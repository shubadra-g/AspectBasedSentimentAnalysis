# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import pos_tag
import numpy as np
import re
from stanfordcorenlp import StanfordCoreNLP
from functools import reduce
from nltk.stem import PorterStemmer#, LancesterStemmer
from collections import Counter 
from nltk.corpus import wordnet 
from nltk.stem import WordNetLemmatizer
from autocorrect import spell

# %%
nlp = StanfordCoreNLP('http://localhost',port=9000)

# %%
# stopwords_set = set(stopwords.words('english'))
stopwords_set = {'i', 'shan', 'just', 'how', 'each', 'out', 'themselves', 'their', 'before', 'were', 'very', 'as', 'further', 'his', 'a', 'once', 'youve', 'y', 'is', 'shouldve', 'youll', 'on', 'd', 'm', 'under', 'haven', 'which', 'only', 'them', 'was', 'by', 'needn', 'whom', 'that', 'when', 's', 'isn', 'its', 'wasn', 'in', 'we', 'theirs', 'those', 'this', 'having', 'and', 'ain', 'most', 'up', 'off', 'being', 'aren', 'shouldn', 'ourselves', 'from', 'down', 'herself', 'her', 'you', 'are', 'its', 'who', 'the', 'here', 'where', 'your', 'youd', 'she', 'didn', 'weren', 'about', 'has', 'our', 'an', 'yourselves', 'or', 'hasn', 'again', 'while', 'does', 'him', 'shes', 'above', 'below', 'itself', 'to', 'through', 'will', 'couldn', 'hers', 'they', 'doing', 'because', 'he', 'what', 'such', 'youre', 'nor', 'too', 'should', 'ours', 'then', 'himself', 'all', 'of', 'mightn', 'between', 'now', 'against', 'some', 'with', 'until', 'am', 'other', 'at', 'can', 'over', 'mustn', 'wouldn', 'do', 'for', 'after', 'hadn', 'me', 'been', 'same', 'doesn', 'my', 'these', 'll', 'did', 'had', 'it', 'so', 'ma', 'during', 'than', 'o', 'yourself', 'own', 'have', 're', 've', 'be', 'why', 't', 'there', 'more', 'won', 'yours', 'few', 'into', 'thatll', 'any', 'myself', 'both', 'don', 'if'}

important_pos_tag_list_at = ['CC', 'JJ', 'JJR', 'JJS', 'NN', 'NNS', 'NNP', 'NNPS', 'RB', 'RBR', 'RBS', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'FW','IN', 'CD']
important_pos_tag_list_sent = ['CC', 'JJ', 'JJR', 'JJS', 'NN', 'NNS', 'NNP', 'NNPS', 'RB', 'RBR', 'RBS', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']
stemmer_tag_list = ['JJ', 'JJR', 'JJS', 'NN', 'NNS', 'RB', 'RBR', 'RBS', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']
sentence_weights = []
data_X, data_Y, data_X1 = [], [], []
porter_stemmer = PorterStemmer()
word_net_lemmatizer = WordNetLemmatizer()

# %%
def get_wordnet_pos(treebank_tag):

    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return ''

# %%
file_name = 'project_2_train/' + 'dara 1_train.csv'
file_obj = open(file_name, 'r')

# %%
for line_index, line in enumerate(file_obj):
    if line_index != 0:
        ''' Splitting the columns based on comma - since it is csv'''
        columns = line.split(',')

        ''' The comma in the actual sentence was represented as [commma] because of csv format, replace that '''
        columns[1] = columns[1].replace('[comma]', ',')
        columns[2] = columns[2].replace('[comma]', ',')

        ''' Some aspect terms are mic in the sentence where computer/mic is present '''
        columns[1] = columns[1].replace('-', ' ')
        columns[2] = columns[2].replace('-', ' ')
        columns[1] = columns[1].replace('/', ' ')
        columns[2] = columns[2].replace('/', ' ')
        
        ''' POS Tagging the sentence'''
        pos_tagged_sentence = nlp.pos_tag(columns[1])
        pos_tagged_aspect_term = nlp.pos_tag(columns[2])
#         porter_stemmer

    
        for word_index, word in enumerate(pos_tagged_sentence):
            pos_tagged_sentence[word_index] = list(word)
            '''Remove special characters'''
            if word[0] not in columns[2]:
                pos_tagged_sentence[word_index][0] = re.sub('[^0-9a-zA-Z]+', '', word[0]).lower()
                ''' didn't is tokenized as did n't hence following code '''
                if pos_tagged_sentence[word_index][0] == 'nt':
                    pos_tagged_sentence[word_index][0] = 'not'
                
        '''Remove empty string tokens'''
        pos_tagged_sentence = [x for x in pos_tagged_sentence if x[0].strip() != '']
        pos_tagged_aspect_term = [x for x in pos_tagged_aspect_term if x[0].strip() != '']
        
        for word_tag_index, word_tag in enumerate(pos_tagged_sentence):
            pos_tagged_sentence[word_tag_index] = list(word_tag)
            if word_tag[1] in stemmer_tag_list and word_tag[0] not in columns[2]:
#                 pos_tagged_sentence[word_tag_index][0] = porter_stemmer.stem(word_tag[0])                
#                 pos_tagged_sentence[word_tag_index][0] = porter_stemmer.stem(word_net_lemmatizer.lemmatize(spell(word_tag[0]), get_wordnet_pos(word_tag[1])))
                pos_tagged_sentence[word_tag_index][0] = word_net_lemmatizer.lemmatize(word_tag[0], get_wordnet_pos(word_tag[1]))
        
        
        ''' For aspect term: Removing the words whose POS tag is not important'''
        columns[2] = []
        for aspect_word_tag in pos_tagged_aspect_term:
            if aspect_word_tag[1] in important_pos_tag_list_at:
                columns[2].append(aspect_word_tag[0].strip())
        
        '''If it removes every word in the aspect term then print'''
        if len(columns[2]) == 0:
            print(pos_tagged_aspect_term)

        ''' For sentence: Removing the words whose POS tag is not important'''
        columns[1] = []
        for word_tag in pos_tagged_sentence:
            if word_tag[1] in important_pos_tag_list_sent or word_tag[0] in columns[2]:
                columns[1].append(word_tag[0].strip())
    
        '''If it removes every word in the sentence then print'''
        if len(columns[1]) == 0:
            print(pos_tagged_sentence)
        
        for word_index, word in enumerate(columns[1]):
            '''Remove special characters'''
            columns[1][word_index] = re.sub('[^0-9a-zA-Z]+', '', word).lower()
            ''' didn't is tokenized as did n't hence following code '''
            if columns[1][word_index] == 'nt':
                columns[1][word_index] = 'not'
        
        for word_index, word in enumerate(columns[2]):
            '''Remove special characters'''
            columns[2][word_index] = re.sub('[^0-9a-zA-Z]+', '', word).lower()
            ''' didn't is tokenized as did n't hence following code '''
            if columns[2][word_index] == 'nt':
                columns[2][word_index] = 'not'
        
        '''Remove empty string tokens'''
        columns[1] = [x.strip() for x in columns[1] if x.strip() != '']
        columns[2] = [x.strip() for x in columns[2] if x.strip() != '']
        
        ''' Remove stop words '''
        columns[2] = [word for word in columns[2] if word not in stopwords_set]
        columns[1] = [word for word in columns[1] if word not in stopwords_set]
        
#         spell
        
        if len(columns[2]) == 0:
            print(pos_tagged_aspect_term)
    
        columns[1] = ' '.join(columns[1])
        columns[2] = ' '.join(columns[2])

        ''' The aspect term location given is not proper - hence extracting the location by ourselves '''
        columns[3] = []
        
        for m in re.finditer(columns[2], columns[1]):
            columns[3].append([m.start(), m.end()])
            
        ''' Tokenizing the words again '''
        columns[1] = columns[1].split(' ')
        columns[2] = columns[2].split(' ')
        
        ''' New column to specify the aspect term location in the list '''
        columns.append([])
        
        ''' for multiple positions of aspect term '''
        for aspect_term_loc in columns[3]:
            if aspect_term_loc[0] == 0: #start index of the 1st occurance of the aspect term
                columns[5].append([0])
            else:
                temp_len = aspect_term_loc[0] # assign the start position of the aspect term
                for word_index, word in enumerate(columns[1]):
                    temp_len -= (len(word) + 1) # Counting the words till the position - +1 for blank space
                    if temp_len == 0: # Reached the aspect word
                        columns[5].append([word_index+1])
                        break
            for k in range(len(columns[2])-1): # if multiple words in the aspect term - tag the following words in the sentence
                columns[5][-1].append(columns[5][-1][-1]+1)

        ''' if not found the aspect term location in the list then do '''
        if len(columns[5]) < 1:
            print(columns)
            print('---------------------------------')
#             continue
        
        word_wt_list = [[word, 0] for word in columns[1]]
        
        ''' run only if aspect term found, otherwise the weights are zero '''
        if len(columns[5]) >= 1:
        
            ''' Assigning weights to every word based on the distance from the aspect term '''
            for j, elem in enumerate(columns[5]):
                for k, word in enumerate(columns[1]):
                    if k < elem[0]: # Word left to the aspect term
                        dist = abs(elem[0] - k)
                        if word_wt_list[k][1] < 1/dist:
                            word_wt_list[k][1] = 1/dist
                    elif k > elem[-1]: # word right to the aspect term : Aspect term can have multiple words
                        dist = abs(k - elem[-1])
                        if word_wt_list[k][1] < 1/dist:
                            word_wt_list[k][1] = 1/dist
                for aspect_word_loc in elem:
                    word_wt_list[aspect_word_loc][1] = 1.5

        ''' For duplicate words - if it's aspect term - add the weights, if not, then take the weight which is greater, make the other weight as zero '''
        for j, word_1 in enumerate(word_wt_list):
            for k, word_2 in enumerate(word_wt_list[j+1:]):
                if word_1[0] == word_2[0]:
                    if word_1[1] == 1.5 and word_2[1] == 1.5:
                        # print(line)
                        # print(word_wt_list)
                        word_1[1] += 1.5
                        word_2[1] = 0
                    elif word_1[1] < word_2[1]:
                        # print(line)
                        # print(word_wt_list)
                        word_1[1] = word_2[1]
                        word_2[1] = 0
                    elif word_1[1] > word_2[1]:
                        # print(line)
                        # print(word_wt_list)
                        word_2[1] = 0
                    elif word_1[1] == word_2[1]:
                        word_2[1] = 0
    
        if len(columns[5]) >= 1:
            ''' For removing duplicate words - they have weight zero now'''
            word_wt_list = [elem for elem in word_wt_list if elem[1] != 0]
        else: 
            print(line)
            print(columns)
            print(word_wt_list)

        if len(columns[2]) > 1 and len(columns[5]) > 1:
#             print(line)
#             print(columns)
#             print(word_wt_list)
            pass

        if columns[0] == '2911_0':
#             print(line)
#             print(word_wt_list)
            pass

        '''Removing new line character from columns[4] -  the class column'''
        columns[4] = columns[4].rstrip('\n')
        
        data_X.append(columns[1])
        data_X1.append(' '.join(columns[1]))

        data_Y.append(columns[4])
        sentence_weights.append(word_wt_list)
        
    if line_index == 10:
#         break
        pass
# Out:
# ['1650_0', ['macbook', 'come', 'freesecuritysoftware', 'protect', 'virus', 'intrusive', 'thing', 'downloads', 'internet', 'surfing', 'email'], ['securitysoftware'], [[17, 33]], '1\n', []]
# ---------------------------------
# 1650_0,With the macbook pro it comes with freesecuritysoftware to protect it from viruses and other intrusive things from downloads and internet surfing or emails.,securitysoftware,39--55,1
#
# ['1650_0', ['macbook', 'come', 'freesecuritysoftware', 'protect', 'virus', 'intrusive', 'thing', 'downloads', 'internet', 'surfing', 'email'], ['securitysoftware'], [[17, 33]], '1\n', []]
# [['macbook', 0], ['come', 0], ['freesecuritysoftware', 0], ['protect', 0], ['virus', 0], ['intrusive', 0], ['thing', 0], ['downloads', 0], ['internet', 0], ['surfing', 0], ['email', 0]]
# ['2261_1', ['apple', 'application', 'exiphoto', 'fun', 'easy', 'really', 'cool', 'use', 'competition'], ['iphoto'], [[20, 26]], '1\n', []]
# ---------------------------------
# 2261_1,The Apple applications (ex.iPhoto) are fun[comma] easy[comma] and really cool to use (unlike the competition)!,iPhoto,27--33,1
#
# ['2261_1', ['apple', 'application', 'exiphoto', 'fun', 'easy', 'really', 'cool', 'use', 'competition'], ['iphoto'], [[20, 26]], '1\n', []]
# [['apple', 0], ['application', 0], ['exiphoto', 0], ['fun', 0], ['easy', 0], ['really', 0], ['cool', 0], ['use', 0], ['competition', 0]]

# %%
file_obj.close()

# %%
'''Building vocabulary and counting word occurances'''

X_reduced = reduce(lambda x1, x2: x1 + x2, data_X)
vocab = list(set(X_reduced))
print(len(vocab))
# Out:
# 2429

# %%
weight_v = np.zeros_like(vocab, dtype = np.float_)
weight_x = []

# %%
pf = open('weightxy_data1_spell_lemm.csv', 'w')

# %%
''' Writing column labels for pandas dataframe'''
pf.write(','.join(vocab))
pf.write(',class_')
pf.write('\n')
# Out:
# 1

# %%
for i, sentence in enumerate(sentence_weights):
    for word in sentence:
        v_index = vocab.index(word[0])
        weight_v[v_index] = word[1]

    weight_x.append(weight_v)
    if len(sentence) != weight_v[np.where(weight_v > 0)].shape[0]:
        print(sentence)
        print(len(sentence))
        print(weight_v[np.where(weight_v > 0)])

    ''' code to write the data to file '''
    temp = [str(j) for j in weight_v.tolist()]
    pf.write(','.join(temp))
    if len(weight_v[np.where(weight_v > 0)]) == 0 :
        pf.write(','+str(0))
        print('ksdjnfsdnfk')
    else:
        pf.write(','+str(data_Y[i]))
    pf.write('\n')
    weight_v = np.zeros_like(weight_v)
# Out:
# [['macbook', 0], ['come', 0], ['freesecuritysoftware', 0], ['protect', 0], ['virus', 0], ['intrusive', 0], ['thing', 0], ['downloads', 0], ['internet', 0], ['surfing', 0], ['email', 0]]
# 11
# []
# ksdjnfsdnfk
# [['apple', 0], ['application', 0], ['exiphoto', 0], ['fun', 0], ['easy', 0], ['really', 0], ['cool', 0], ['use', 0], ['competition', 0]]
# 9
# []
# ksdjnfsdnfk

# %%
pf.close()

# %%
weight_x = np.array(weight_x)

print(weight_x.shape)
# Out:
# (2313, 2429)

# %%
test_sentence_weights = []
test_data_X, test_data_Y, test_data_X1 = [], [], []

# %%
file_name = 'project_2_test/' + 'LaptopDataTrial_data1.csv'
file_obj = open(file_name, 'r')

# %%
for line_index, line in enumerate(file_obj):
    if line_index != 0:
        ''' Splitting the columns based on comma - since it is csv'''
        columns = line.split(',')

        ''' The comma in the actual sentence was represented as [commma] because of csv format, replace that '''
        columns[1] = columns[1].replace('[comma]', ',')
        columns[2] = columns[2].replace('[comma]', ',')

        ''' Some aspect terms are mic in the sentence where computer/mic is present '''
        columns[1] = columns[1].replace('-', ' ')
        columns[2] = columns[2].replace('-', ' ')
        columns[1] = columns[1].replace('/', ' ')
        columns[2] = columns[2].replace('/', ' ')
        
        ''' POS Tagging the sentence'''
        pos_tagged_sentence = nlp.pos_tag(columns[1])
        pos_tagged_aspect_term = nlp.pos_tag(columns[2])
#         porter_stemmer

    
        for word_index, word in enumerate(pos_tagged_sentence):
            pos_tagged_sentence[word_index] = list(word)
            '''Remove special characters'''
            if word[0] not in columns[2]:
                pos_tagged_sentence[word_index][0] = re.sub('[^0-9a-zA-Z]+', '', word[0]).lower()
                ''' didn't is tokenized as did n't hence following code '''
                if pos_tagged_sentence[word_index][0] == 'nt':
                    pos_tagged_sentence[word_index][0] = 'not'
                
        '''Remove empty string tokens'''
        pos_tagged_sentence = [x for x in pos_tagged_sentence if x[0].strip() != '']
        pos_tagged_aspect_term = [x for x in pos_tagged_aspect_term if x[0].strip() != '']
        
        for word_tag_index, word_tag in enumerate(pos_tagged_sentence):
            pos_tagged_sentence[word_tag_index] = list(word_tag)
            if word_tag[1] in stemmer_tag_list and word_tag[0] not in columns[2]:
#                 pos_tagged_sentence[word_tag_index][0] = porter_stemmer.stem(word_tag[0])                
#                 pos_tagged_sentence[word_tag_index][0] = porter_stemmer.stem(word_net_lemmatizer.lemmatize(spell(word_tag[0]), get_wordnet_pos(word_tag[1])))
                pos_tagged_sentence[word_tag_index][0] = word_net_lemmatizer.lemmatize(word_tag[0], get_wordnet_pos(word_tag[1]))
        
        
        ''' For aspect term: Removing the words whose POS tag is not important'''
        columns[2] = []
        for aspect_word_tag in pos_tagged_aspect_term:
            if aspect_word_tag[1] in important_pos_tag_list_at:
                columns[2].append(aspect_word_tag[0].strip())
        
        '''If it removes every word in the aspect term then print'''
        if len(columns[2]) == 0:
            print(pos_tagged_aspect_term)

        ''' For sentence: Removing the words whose POS tag is not important'''
        columns[1] = []
        for word_tag in pos_tagged_sentence:
            if word_tag[1] in important_pos_tag_list_sent or word_tag[0] in columns[2]:
                columns[1].append(word_tag[0].strip())
    
        '''If it removes every word in the sentence then print'''
        if len(columns[1]) == 0:
            print(pos_tagged_sentence)
        
        for word_index, word in enumerate(columns[1]):
            '''Remove special characters'''
            columns[1][word_index] = re.sub('[^0-9a-zA-Z]+', '', word).lower()
            ''' didn't is tokenized as did n't hence following code '''
            if columns[1][word_index] == 'nt':
                columns[1][word_index] = 'not'
        
        for word_index, word in enumerate(columns[2]):
            '''Remove special characters'''
            columns[2][word_index] = re.sub('[^0-9a-zA-Z]+', '', word).lower()
            ''' didn't is tokenized as did n't hence following code '''
            if columns[2][word_index] == 'nt':
                columns[2][word_index] = 'not'
        
        '''Remove empty string tokens'''
        columns[1] = [x.strip() for x in columns[1] if x.strip() != '']
        columns[2] = [x.strip() for x in columns[2] if x.strip() != '']
        
        ''' Remove stop words '''
        columns[2] = [word for word in columns[2] if word not in stopwords_set]
        columns[1] = [word for word in columns[1] if word not in stopwords_set]
        
#         spell
        
        if len(columns[2]) == 0:
            print(pos_tagged_aspect_term)
    
        columns[1] = ' '.join(columns[1])
        columns[2] = ' '.join(columns[2])

        ''' The aspect term location given is not proper - hence extracting the location by ourselves '''
        columns[3] = []
        
        for m in re.finditer(columns[2], columns[1]):
            columns[3].append([m.start(), m.end()])
            
        ''' Tokenizing the words again '''
        columns[1] = columns[1].split(' ')
        columns[2] = columns[2].split(' ')
        
        ''' New column to specify the aspect term location in the list '''
        columns.append([])
        
        ''' for multiple positions of aspect term '''
        for aspect_term_loc in columns[3]:
            if aspect_term_loc[0] == 0: #start index of the 1st occurance of the aspect term
                columns[5].append([0])
            else:
                temp_len = aspect_term_loc[0] # assign the start position of the aspect term
                for word_index, word in enumerate(columns[1]):
                    temp_len -= (len(word) + 1) # Counting the words till the position - +1 for blank space
                    if temp_len == 0: # Reached the aspect word
                        columns[5].append([word_index+1])
                        break
            for k in range(len(columns[2])-1): # if multiple words in the aspect term - tag the following words in the sentence
                columns[5][-1].append(columns[5][-1][-1]+1)

        ''' if not found the aspect term location in the list then do '''
        if len(columns[5]) < 1:
            print(columns)
            print('---------------------------------')
#             continue
        
        word_wt_list = [[word, 0] for word in columns[1]]
        
        ''' run only if aspect term found, otherwise the weights are zero '''
        if len(columns[5]) >= 1:
        
            ''' Assigning weights to every word based on the distance from the aspect term '''
            for j, elem in enumerate(columns[5]):
                for k, word in enumerate(columns[1]):
                    if k < elem[0]: # Word left to the aspect term
                        dist = abs(elem[0] - k)
                        if word_wt_list[k][1] < 1/dist:
                            word_wt_list[k][1] = 1/dist
                    elif k > elem[-1]: # word right to the aspect term : Aspect term can have multiple words
                        dist = abs(k - elem[-1])
                        if word_wt_list[k][1] < 1/dist:
                            word_wt_list[k][1] = 1/dist
                for aspect_word_loc in elem:
                    word_wt_list[aspect_word_loc][1] = 1.5

        ''' For duplicate words - if it's aspect term - add the weights, if not, then take the weight which is greater, make the other weight as zero '''
        for j, word_1 in enumerate(word_wt_list):
            for k, word_2 in enumerate(word_wt_list[j+1:]):
                if word_1[0] == word_2[0]:
                    if word_1[1] == 1.5 and word_2[1] == 1.5:
                        # print(line)
                        # print(word_wt_list)
                        word_1[1] += 1.5
                        word_2[1] = 0
                    elif word_1[1] < word_2[1]:
                        # print(line)
                        # print(word_wt_list)
                        word_1[1] = word_2[1]
                        word_2[1] = 0
                    elif word_1[1] > word_2[1]:
                        # print(line)
                        # print(word_wt_list)
                        word_2[1] = 0
                    elif word_1[1] == word_2[1]:
                        word_2[1] = 0
    
        if len(columns[5]) >= 1:
            ''' For removing duplicate words - they have weight zero now'''
            word_wt_list = [elem for elem in word_wt_list if elem[1] != 0]
        else: 
            print(line)
            print(columns)
            print(word_wt_list)

        if len(columns[2]) > 1 and len(columns[5]) > 1:
#             print(line)
#             print(columns)
#             print(word_wt_list)
            pass

        if columns[0] == '2911_0':
#             print(line)
#             print(word_wt_list)
            pass

        '''Removing new line character from columns[4] -  the class column'''
        columns[4] = columns[4].rstrip('\n')
        
        test_data_X.append(columns[1])
        test_data_X1.append(' '.join(columns[1]))

        test_data_Y.append(columns[4])
        test_sentence_weights.append(word_wt_list)
        
    if line_index == 10:
#         break
        pass

# %%
file_obj.close()

# %%
test_weight_v = np.zeros_like(vocab, dtype = np.float_)
test_weight_x = []

# %%
pf = open('weightxy_test1_spell_lemm.csv', 'w')

# %%
''' Writing column labels for pandas dataframe'''
pf.write(','.join(vocab))
pf.write(',class_') # comment this for final TODO
pf.write('\n')
# Out:
# 1

# %%
for i, sentence in enumerate(test_sentence_weights):
    for word in sentence:
        v_index = vocab.index(word[0])
        test_weight_v[v_index] = word[1]

    test_weight_x.append(test_weight_v)
    if len(sentence) != test_weight_v[np.where(test_weight_v > 0)].shape[0]:
        print(sentence)
        print(len(sentence))
        print(test_weight_v[np.where(test_weight_v > 0)])

    ''' code to write the data to file '''
    temp = [str(j) for j in test_weight_v.tolist()]
    pf.write(','.join(temp))
    if len(weight_v[np.where(weight_v > 0)]) == 0 :
        pf.write(','+str(0))
        print('ksdjnfsdnfk')
    else:
        pf.write(','+str(test_data_Y[i]))
    pf.write('\n')
    weight_v = np.zeros_like(weight_v)
# Out:
# ksdjnfsdnfk
# [['lightweight', 1.0], ['screen', 1.5], ['beautiful', 1.0]]
# 3
# [1.  1.5 1.  1.  1.5 1.5]
# ksdjnfsdnfk
# [['build', 1.5], ['quality', 1.5], ['performance', 1.0], ['everything', 0.5], ['sub', 0.3333333333333333], ['par', 0.25], ['expect', 0.2], ['apple', 0.16666666666666666]]
# 8
# [0.33333333 1.5        1.         0.25       1.5        1.
#  1.         0.5        1.         1.5        0.2        1.5
#  0.16666667 1.5       ]
# ksdjnfsdnfk
# [['build', 0.5], ['quality', 1.0], ['performance', 1.5], ['everything', 1.0], ['sub', 0.5], ['par', 0.3333333333333333], ['expect', 0.25], ['apple', 0.2]]
# 8
# [0.5        0.5        1.         0.33333333 1.5        1.
#  1.5        1.         1.         1.5        0.25       1.
#  0.2        1.5       ]
# ksdjnfsdnfk
# [['truly', 0.3333333333333333], ['great', 0.5], ['computer', 1.0], ['costing', 1.5], ['less', 1.0], ['buck', 0.5], ['tax', 0.3333333333333333]]
# 7
# [0.33333333 0.5        0.5        0.5        1.         0.33333333
#  1.5        1.         1.5        1.         1.         0.33333333
#  1.5        1.         0.25       1.         1.         0.2
#  0.5        1.5        1.5       ]
# ksdjnfsdnfk
# [['boots', 1.5], ['fast', 1.0], ['run', 0.5], ['great', 0.3333333333333333]]
# 4
# [0.33333333 0.5        0.33333333 0.5        1.         0.33333333
#  1.5        1.         1.5        1.         1.         0.33333333
#  1.5        1.5        1.         1.         0.25       1.
#  1.         0.2        0.5        1.5        1.5        0.5       ]
# ksdjnfsdnfk
# [['boots', 0.5], ['fast', 1.0], ['runs', 1.5], ['great', 1.0]]
# 4
# [0.33333333 0.5        1.         0.5        1.         0.33333333
#  1.5        1.         1.5        1.         1.5        1.
#  0.33333333 1.5        0.5        1.         1.         0.25
#  1.         1.         0.2        0.5        1.5        1.5
#  0.5       ]
# ksdjnfsdnfk
# [['call', 1.0], ['tech', 1.5], ['support', 1.5], ['standard', 1.0], ['email', 0.5], ['form', 0.3333333333333333], ['fax', 0.25], ['back', 0.2]]
# 8
# [1.         0.33333333 0.5        1.         0.5        1.
#  0.33333333 1.5        1.         1.         1.5        1.
#  0.33333333 0.25       0.2        1.5        1.         0.33333333
#  1.5        0.5        1.         1.         1.5        0.25
#  1.         1.         1.5        0.2        0.5        1.5
#  0.5        1.5        0.5       ]
# ksdjnfsdnfk
# [['service', 1.5], ['receive', 1.0], ['toshiba', 0.5], ['go', 0.3333333333333333], ['call', 0.25], ['duty', 0.2]]
# 6
# [1.         0.33333333 0.5        1.         0.5        1.
#  0.33333333 1.         1.5        1.         0.25       1.5
#  1.         0.33333333 0.25       0.2        1.5        1.
#  0.33333333 1.5        0.5        1.         0.5        1.
#  1.5        1.5        0.25       0.2        1.         1.
#  1.5        0.2        0.5        1.5        0.5        1.5
#  0.5        0.33333333]
# ksdjnfsdnfk
# [['recommend', 1.0], ['internet', 1.5], ['speed', 1.5], ['probably', 1.0], ['thats', 0.5], ['thing', 0.3333333333333333], ['really', 0.25], ['care', 0.2]]
# 8
# [1.         0.33333333 0.5        1.         0.25       0.33333333
#  0.5        1.         0.33333333 1.         1.5        0.5
#  1.         0.25       1.5        1.         0.33333333 1.
#  0.25       0.2        1.5        1.5        1.         0.33333333
#  1.5        0.5        1.         0.2        0.5        1.
#  1.5        1.5        1.         0.25       0.2        1.
#  1.         1.5        0.2        0.5        1.5        0.5
#  1.5        0.5        0.33333333 1.5       ]
# ksdjnfsdnfk
# [['screen', 1.5], ['show', 1.0], ['great', 0.5], ['color', 0.3333333333333333]]
# 4
# [1.         0.33333333 0.5        0.5        0.25       0.33333333
#  0.5        1.         0.33333333 1.         1.         1.5
#  0.5        1.         0.25       1.5        1.         0.33333333
#  0.33333333 1.         0.25       0.2        1.5        1.5
#  1.         0.33333333 1.5        0.5        1.         0.2
#  0.5        1.         1.5        1.5        1.         0.25
#  0.2        1.         1.         1.5        0.2        0.5
#  1.5        0.5        1.5        0.5        0.33333333 1.5       ]
# ksdjnfsdnfk
# [['battery', 1.5], ['life', 1.5], ['not', 1.0], ['decrease', 0.5], ['buy', 0.3333333333333333], ['thrill', 0.25]]
# 6
# [0.25       1.         0.33333333 0.5        0.5        0.25
#  0.33333333 0.5        1.         0.33333333 1.         1.
#  1.5        0.5        0.5        1.         0.33333333 0.25
#  1.5        1.         0.33333333 0.33333333 1.         0.25
#  1.5        0.2        1.5        1.5        1.         1.
#  1.5        0.33333333 1.5        0.5        1.         0.2
#  0.5        1.         1.5        1.5        1.         0.25
#  0.2        1.         1.         1.5        0.2        0.5
#  1.5        0.5        1.5        0.5        0.33333333 1.5       ]
# ksdjnfsdnfk
# [['price', 1.5], ['feature', 1.0], ['meet', 0.5], ['need', 0.3333333333333333]]
# 4
# [0.25       1.         0.33333333 0.5        0.5        0.25
#  0.33333333 0.5        1.         0.33333333 1.         1.
#  1.5        0.5        0.5        1.         0.33333333 0.25
#  1.5        1.         0.33333333 0.33333333 1.         0.25
#  1.5        1.         0.2        1.5        1.5        1.
#  1.         1.5        0.33333333 1.5        0.5        1.5
#  1.         0.2        0.5        1.         1.5        1.5
#  0.5        1.         0.25       0.2        1.         1.
#  1.5        0.2        0.5        1.5        0.33333333 0.5
#  1.5        0.5        0.33333333 1.5       ]
# ksdjnfsdnfk
# [['price', 1.0], ['features', 1.5], ['meet', 1.0], ['need', 0.5]]
# 4
# [0.25       1.         0.33333333 0.5        0.5        0.25
#  0.33333333 0.5        1.         0.33333333 1.5        1.
#  1.         1.5        0.5        0.5        1.         0.33333333
#  0.25       1.5        1.         0.33333333 0.33333333 1.
#  0.25       1.5        1.         0.2        1.5        1.5
#  1.         1.         1.5        0.33333333 1.5        0.5
#  1.         1.         0.2        0.5        1.         1.5
#  1.5        1.         1.         0.25       0.2        1.
#  1.         1.5        0.2        0.5        1.5        0.5
#  0.5        1.5        0.5        0.33333333 1.5       ]
# ksdjnfsdnfk
# [['mouse', 1.5], ['buttons', 1.5], ['hard', 1.0], ['push', 0.5]]
# 4
# [1.5        0.25       1.         1.5        0.33333333 0.5
#  0.5        0.5        0.25       0.33333333 0.5        1.
#  0.33333333 1.5        1.         1.         1.5        0.5
#  0.5        1.         0.33333333 0.25       1.5        1.
#  0.33333333 0.33333333 1.         0.25       1.5        1.
#  0.2        1.5        1.5        1.         1.         1.5
#  0.33333333 1.5        0.5        1.         1.         0.2
#  0.5        1.         1.         1.5        1.5        1.
#  1.         0.25       0.2        1.         1.         1.5
#  0.2        0.5        1.5        0.5        0.5        1.5
#  0.5        0.33333333 1.5       ]
# ksdjnfsdnfk
# [['complete', 0.3333333333333333], ['opposite', 0.5], ['ergonomic', 1.0], ['design', 1.5]]
# 4
# [1.5        0.25       1.         1.         1.5        0.33333333
#  0.5        0.5        1.5        0.5        0.25       0.33333333
#  0.5        1.         0.33333333 1.5        1.         1.
#  1.5        0.33333333 0.5        0.5        1.         0.33333333
#  0.25       1.5        1.         0.33333333 0.33333333 1.
#  0.25       1.5        1.         0.2        1.5        1.5
#  1.         1.         1.5        0.33333333 1.5        0.5
#  1.         1.         0.2        0.5        1.         1.
#  1.5        1.5        1.         1.         0.5        0.25
#  0.2        1.         1.         1.5        0.2        0.5
#  1.5        0.5        0.5        1.5        0.5        0.33333333
#  1.5       ]
# ksdjnfsdnfk
# [['technical', 1.5], ['service', 1.5], ['dell', 1.0], ['3rd', 0.5], ['world', 0.3333333333333333], ['well', 0.25], ['not', 0.2], ['even', 0.16666666666666666], ['bother', 0.14285714285714285]]
# 9
# [1.5        0.25       1.         1.         1.         1.5
#  0.33333333 0.5        0.5        1.5        0.16666667 0.5
#  0.5        0.25       0.33333333 0.5        1.         0.33333333
#  1.5        1.         1.         1.5        0.33333333 0.5
#  0.5        1.         0.33333333 0.25       1.5        1.
#  0.33333333 0.33333333 1.         0.25       1.5        1.
#  0.2        1.5        1.5        0.2        1.         0.25
#  1.5        0.33333333 1.5        0.5        1.         1.5
#  1.         0.2        0.5        0.14285714 1.         1.
#  1.5        1.5        1.         1.         0.5        0.25
#  0.2        1.         1.         0.33333333 1.5        0.2
#  0.5        1.5        0.5        0.5        1.5        0.5
#  0.33333333 1.5       ]
# ksdjnfsdnfk
# [['built', 1.5], ['camera', 1.5], ['useful', 1.0], ['chat', 0.5], ['tech', 0.3333333333333333], ['remote', 0.25], ['building', 0.2], ['campus', 0.16666666666666666]]
# 8
# [1.5        0.25       1.         1.         1.         1.5
#  0.33333333 0.5        0.5        1.5        0.16666667 1.5
#  0.5        0.5        0.25       0.33333333 0.5        1.
#  0.33333333 1.5        1.         1.         1.5        0.33333333
#  0.5        0.5        1.5        1.         0.33333333 0.25
#  1.5        1.         0.33333333 0.33333333 1.         0.25
#  1.5        1.         0.2        1.5        1.5        0.2
#  1.         0.25       1.5        0.33333333 1.5        0.5
#  1.         0.16666667 1.5        1.         0.2        0.5
#  0.25       0.5        0.14285714 1.         1.         1.5
#  1.5        1.         1.         0.5        0.25       0.2
#  1.         1.         0.33333333 0.33333333 0.2        1.
#  0.5        1.5        0.5        0.5        1.5        0.5
#  0.33333333 0.2        1.5       ]
# ksdjnfsdnfk
# [['keyboard', 1.5], ['good', 1.0], ['size', 0.5], ['wasy', 0.3333333333333333], ['use', 0.25]]
# 5
# [1.5        0.25       1.         1.         1.         1.5
#  0.33333333 0.5        0.5        1.5        0.16666667 1.5
#  0.5        0.5        0.25       0.33333333 0.5        1.
#  0.33333333 1.5        0.25       1.         1.         1.5
#  0.33333333 0.5        0.5        1.5        1.         0.33333333
#  0.25       1.5        1.         0.33333333 0.33333333 1.
#  0.25       1.5        1.         0.2        1.5        1.5
#  0.2        1.         1.         0.25       1.5        0.33333333
#  1.5        0.5        1.         0.16666667 1.5        1.
#  0.2        0.5        0.25       0.5        0.14285714 1.
#  1.         1.5        1.5        1.         0.33333333 1.
#  0.5        0.25       0.2        1.         1.         0.33333333
#  0.33333333 0.2        1.         0.5        1.5        1.5
#  0.5        0.5        0.5        1.5        0.5        0.33333333
#  0.2        1.5       ]
# ksdjnfsdnfk
# [['great', 1.0], ['wifi', 1.5]]
# 2
# [1.5        0.25       1.         1.         1.         1.5
#  0.33333333 0.5        1.         1.5        0.16666667 1.5
#  0.5        0.5        0.25       0.33333333 0.5        1.
#  0.33333333 1.5        0.25       1.         1.         1.5
#  0.33333333 0.5        0.5        1.5        1.         0.33333333
#  0.25       1.5        1.         0.33333333 0.33333333 1.
#  0.25       1.5        1.         0.2        1.5        1.5
#  0.2        1.         1.         0.25       1.5        0.33333333
#  1.5        0.5        1.         0.16666667 1.5        1.
#  0.2        0.5        0.25       0.5        0.14285714 1.
#  1.         1.5        1.5        1.         0.33333333 1.
#  0.5        0.25       0.2        1.5        1.         1.
#  0.33333333 0.33333333 0.2        1.         0.5        1.5
#  1.5        0.5        0.5        0.5        1.5        0.5
#  0.33333333 0.2        1.5       ]
# ksdjnfsdnfk
# [['games', 1.5], ['main', 1.0], ['issue', 0.5]]
# 3
# [1.5        0.25       1.         1.         1.         1.5
#  0.33333333 0.5        1.         1.5        0.16666667 1.5
#  0.5        0.5        0.25       0.33333333 0.5        1.
#  0.33333333 1.5        0.25       1.         1.         1.5
#  0.33333333 0.5        1.5        0.5        1.5        1.
#  0.33333333 0.25       1.5        1.         0.33333333 0.33333333
#  1.         0.25       0.5        1.5        1.         0.2
#  1.5        1.5        0.2        1.         1.         0.25
#  1.5        0.33333333 1.5        0.5        1.         0.16666667
#  1.5        1.         0.2        0.5        0.25       0.5
#  0.14285714 1.         1.         1.5        1.5        1.
#  0.33333333 1.         0.5        0.25       0.2        1.5
#  1.         1.         0.33333333 0.33333333 0.2        1.
#  0.5        1.5        1.5        0.5        0.5        0.5
#  1.5        1.         0.5        0.33333333 0.2        1.5       ]
# ksdjnfsdnfk
# [['price', 1.5], ['drive', 1.0], ['influence', 0.5], ['make', 0.3333333333333333], ['purchase', 0.25], ['laptop', 0.2]]
# 6
# [1.5        0.25       1.         1.         1.         1.5
#  0.33333333 0.5        1.         1.5        0.16666667 1.5
#  0.5        0.25       0.5        0.25       0.33333333 0.5
#  1.         0.33333333 1.5        0.25       1.         1.
#  1.5        0.33333333 0.5        1.5        1.         0.5
#  1.5        1.         0.33333333 0.25       1.5        1.
#  0.33333333 0.33333333 1.         0.25       0.5        1.5
#  1.         0.33333333 0.2        1.5        1.5        0.2
#  1.         1.         0.25       1.5        0.33333333 1.5
#  0.5        1.5        0.16666667 1.5        1.         0.2
#  0.5        0.25       0.5        0.14285714 1.         1.
#  1.5        1.5        1.         0.33333333 1.         0.5
#  0.25       0.2        0.5        1.5        1.         1.
#  0.33333333 0.33333333 0.2        1.         0.5        1.5
#  1.5        0.5        0.5        0.5        0.2        1.5
#  1.         0.5        0.33333333 0.2        1.5       ]
# ksdjnfsdnfk
# [['but', 1.0], ['see', 0.2], ['macbook', 0.25], ['pro', 0.3333333333333333], ['different', 0.5], ['huge', 1.0], ['price', 1.5], ['tag', 1.5], ['come', 0.5], ['full', 0.3333333333333333], ['software', 0.25], ['actually', 0.2], ['need', 0.16666666666666666], ['free', 0.14285714285714285], ['future', 0.125], ['update', 0.1111111111111111]]
# 16
# [1.5        0.25       1.         1.         1.         1.5
#  0.5        0.33333333 0.5        1.         1.5        0.16666667
#  1.5        0.5        0.25       0.5        0.25       0.33333333
#  0.125      0.5        0.5        1.         0.33333333 1.5
#  1.         0.25       0.33333333 1.         1.         1.5
#  0.33333333 0.5        1.5        1.         0.5        1.5
#  1.         0.33333333 0.25       1.5        1.         0.33333333
#  0.33333333 1.         0.25       0.5        1.5        1.
#  0.33333333 0.2        1.5        1.5        0.2        1.
#  1.         1.         0.25       1.5        0.33333333 0.11111111
#  0.33333333 1.5        0.5        1.5        0.16666667 1.5
#  1.         0.2        0.5        0.25       0.5        0.14285714
#  0.14285714 1.         1.         1.5        0.25       0.25
#  1.5        1.         0.33333333 1.         0.5        0.25
#  0.2        0.5        1.5        1.         1.         0.33333333
#  0.33333333 0.2        1.5        1.         0.5        1.5
#  1.5        0.16666667 0.5        0.2        0.5        0.2
#  1.5        0.2        1.         0.5        0.33333333 0.2
#  1.5       ]
# ksdjnfsdnfk
# [['but', 0.3333333333333333], ['see', 0.1], ['macbook', 0.1111111111111111], ['pro', 0.125], ['different', 0.14285714285714285], ['huge', 0.16666666666666666], ['price', 0.2], ['tag', 0.25], ['come', 0.5], ['full', 1.0], ['software', 1.5], ['actually', 1.0], ['need', 0.5], ['free', 0.3333333333333333], ['future', 0.25], ['update', 0.2]]
# 16
# [1.5        0.25       1.         1.         1.         1.5
#  0.5        0.33333333 0.5        1.         1.5        0.16666667
#  1.5        0.5        0.25       0.5        0.25       0.33333333
#  0.25       0.5        0.14285714 1.         0.33333333 1.5
#  0.33333333 0.25       1.         1.         1.         1.5
#  0.33333333 0.5        1.5        1.         0.5        1.5
#  1.         0.33333333 0.25       1.5        1.         0.33333333
#  0.33333333 1.         0.25       0.5        1.5        1.
#  0.33333333 0.2        1.5        1.5        0.2        0.16666667
#  1.         1.         0.25       1.5        0.33333333 0.2
#  0.125      1.5        0.5        0.2        0.16666667 1.5
#  1.         0.2        0.5        0.25       0.5        0.14285714
#  0.33333333 1.         1.         1.5        0.11111111 1.5
#  1.5        1.         0.33333333 1.         0.5        0.25
#  0.2        0.5        1.5        1.         1.         0.33333333
#  0.33333333 0.2        0.25       1.         0.5        1.5
#  1.5        0.5        0.5        0.1        0.5        0.2
#  1.5        1.         1.         0.5        0.33333333 0.2
#  1.5       ]
# ksdjnfsdnfk
# [['but', 0.125], ['see', 0.06666666666666667], ['macbook', 0.07142857142857142], ['pro', 0.07692307692307693], ['different', 0.08333333333333333], ['huge', 0.09090909090909091], ['price', 0.1], ['tag', 0.1111111111111111], ['come', 0.14285714285714285], ['full', 0.16666666666666666], ['software', 0.2], ['actually', 0.25], ['need', 0.3333333333333333], ['free', 0.5], ['future', 1.0], ['updates', 1.5]]
# 16
# [1.5        0.25       1.         1.         1.         1.5
#  0.14285714 0.33333333 0.5        1.         1.5        1.5
#  0.16666667 1.5        0.5        0.25       0.5        0.25
#  0.33333333 1.         0.5        0.08333333 1.         0.33333333
#  1.5        0.125      0.25       0.16666667 1.         1.
#  1.5        0.33333333 0.5        1.5        1.         0.5
#  1.5        1.         0.33333333 0.25       1.5        1.
#  0.33333333 0.33333333 1.         0.25       0.5        1.5
#  1.         0.33333333 0.2        1.5        1.5        0.2
#  0.09090909 1.         1.         0.25       1.5        0.33333333
#  0.2        0.07692308 1.5        0.5        0.1        0.16666667
#  1.5        1.         0.2        0.5        0.25       0.5
#  0.14285714 0.5        1.         1.         1.5        0.07142857
#  0.2        1.5        1.         0.33333333 1.         0.5
#  0.25       0.2        0.5        1.5        1.         1.
#  0.33333333 0.33333333 0.2        0.11111111 1.         0.5
#  1.5        1.5        0.33333333 0.5        0.06666667 0.5
#  0.2        1.5        0.25       1.         0.5        0.33333333
#  0.2        1.5       ]
# ksdjnfsdnfk
# [['great', 1.0], ['product', 0.5], ['price', 1.5]]
# 3
# [1.5        0.25       1.         1.         1.         0.5
#  1.5        0.14285714 0.33333333 0.5        1.         1.5
#  1.5        0.16666667 1.5        0.5        0.25       0.5
#  0.25       0.33333333 1.         0.5        0.08333333 1.
#  0.33333333 1.5        0.125      0.25       0.16666667 1.
#  1.         1.5        0.33333333 0.5        1.5        1.
#  0.5        1.5        1.         0.33333333 0.25       1.5
#  1.         0.33333333 0.33333333 1.         0.25       0.5
#  1.5        1.         0.33333333 0.2        1.5        1.5
#  0.2        0.09090909 1.         1.         0.25       1.5
#  0.33333333 0.2        0.07692308 1.5        0.5        1.5
#  0.16666667 1.5        1.         0.2        0.5        0.25
#  0.5        0.14285714 0.5        1.         1.         1.5
#  0.07142857 0.2        1.5        1.         0.33333333 1.
#  0.5        0.25       0.2        0.5        1.5        1.
#  1.         0.33333333 0.33333333 0.2        0.11111111 1.
#  0.5        1.5        1.5        0.33333333 0.5        0.06666667
#  0.5        0.2        1.5        0.25       1.         0.5
#  0.33333333 0.2        1.5       ]
# ksdjnfsdnfk
# [['excellent', 1.0], ['speed', 1.5], ['processing', 1.0], ['data', 0.5]]
# 4
# [1.5        1.         0.25       1.         1.         1.
#  0.5        1.5        0.14285714 0.33333333 0.5        1.
#  1.5        1.5        0.16666667 1.5        0.5        0.25
#  0.5        0.25       0.33333333 1.         0.5        0.08333333
#  1.         0.33333333 1.5        0.125      0.25       0.16666667
#  0.5        1.         1.         1.5        0.33333333 0.5
#  1.5        1.         0.5        1.5        1.         0.33333333
#  0.25       1.5        1.         0.33333333 0.33333333 1.
#  0.25       0.5        1.5        1.         0.33333333 0.2
#  1.5        1.5        0.2        0.09090909 1.         1.
#  0.25       1.5        0.33333333 0.2        0.07692308 1.5
#  0.5        1.5        0.16666667 1.5        1.         0.2
#  0.5        0.25       0.5        0.14285714 0.5        1.
#  1.         1.5        0.07142857 0.2        1.5        1.
#  0.33333333 1.         0.5        0.25       0.2        0.5
#  1.5        1.         1.         0.33333333 0.33333333 0.2
#  0.11111111 1.         0.5        1.5        1.5        0.33333333
#  0.5        0.06666667 0.5        0.2        1.5        0.25
#  1.         0.5        0.33333333 0.2        1.         1.5       ]
# ksdjnfsdnfk
# [['macbook', 0.3333333333333333], ['arrive', 0.5], ['nice', 1.0], ['twin', 1.5], ['packing', 1.5], ['seal', 1.0], ['box', 0.5], ['function', 0.3333333333333333], ['work', 0.25], ['great', 0.2]]
# 10
# [1.5        1.5        1.         0.25       1.         1.
#  1.         0.5        1.5        0.14285714 0.33333333 0.5
#  0.2        1.5        1.5        0.25       0.16666667 1.5
#  0.5        0.25       0.5        0.25       0.33333333 1.
#  0.5        0.08333333 1.         0.33333333 1.5        0.125
#  0.25       0.16666667 0.5        1.         1.         1.5
#  0.33333333 0.5        1.5        1.         0.5        1.5
#  1.         0.33333333 0.25       1.5        1.         0.33333333
#  0.33333333 1.         0.25       0.5        1.5        1.
#  0.33333333 0.2        1.5        1.5        1.         0.2
#  0.09090909 1.5        1.         1.         0.25       1.5
#  0.33333333 0.2        0.07692308 1.5        0.33333333 0.5
#  1.5        0.16666667 1.5        1.         0.2        1.
#  0.5        0.25       0.5        0.14285714 0.5        1.
#  1.         1.5        0.33333333 0.2        1.5        1.
#  0.33333333 1.         0.5        0.25       0.2        0.5
#  1.5        1.         1.         0.33333333 0.33333333 0.2
#  0.11111111 1.         0.5        1.5        1.5        0.33333333
#  0.5        0.06666667 0.5        0.2        1.5        0.25
#  1.         0.5        0.33333333 0.5        0.5        0.2
#  1.         1.5       ]
# ksdjnfsdnfk
# [['macbook', 0.14285714285714285], ['arrive', 0.16666666666666666], ['nice', 0.2], ['twin', 0.25], ['packing', 0.3333333333333333], ['seal', 0.5], ['box', 1.0], ['functions', 1.5], ['work', 1.0], ['great', 0.5]]
# 10
# [1.5        0.25       1.5        1.         0.25       1.
#  1.         1.         0.5        1.5        0.14285714 0.33333333
#  0.5        0.5        1.5        1.5        1.         0.16666667
#  1.5        0.5        0.25       0.5        0.25       0.33333333
#  1.         0.5        0.08333333 1.         0.33333333 1.5
#  0.125      0.25       0.16666667 0.5        1.         1.
#  1.5        0.33333333 0.5        1.5        1.         0.5
#  1.5        1.         0.33333333 0.25       1.5        1.
#  0.33333333 0.33333333 1.         0.25       0.5        1.5
#  1.         0.33333333 0.2        1.5        1.5        0.5
#  0.2        0.09090909 0.33333333 1.         1.         0.25
#  1.5        0.33333333 0.2        0.07692308 1.5        0.33333333
#  0.5        1.5        0.16666667 1.5        1.         0.2
#  0.2        0.5        0.25       0.5        0.14285714 0.5
#  1.         1.         1.5        0.14285714 0.2        1.5
#  1.         0.33333333 1.         0.5        0.25       0.2
#  0.5        1.5        1.         1.         0.33333333 0.33333333
#  0.2        0.11111111 1.         0.5        1.5        1.5
#  0.33333333 0.5        0.06666667 0.5        0.2        1.5
#  0.25       1.         0.5        0.33333333 1.         0.16666667
#  0.2        1.         1.5       ]
# ksdjnfsdnfk
# [['switchable', 1.5], ['graphic', 1.5], ['card', 1.5], ['pretty', 1.0], ['sweet', 0.5], ['want', 0.3333333333333333], ['gaming', 0.25], ['laptop', 0.2]]
# 8
# [1.5        0.25       1.5        1.         0.25       1.
#  1.         1.         0.5        1.5        0.14285714 0.33333333
#  0.5        0.5        1.5        1.5        1.         0.16666667
#  1.5        0.5        0.25       0.5        0.25       0.33333333
#  1.         0.5        0.08333333 1.         0.33333333 1.5
#  0.125      0.25       0.16666667 0.5        1.         1.
#  1.5        0.33333333 0.5        1.5        1.         0.5
#  1.5        1.         0.33333333 0.25       1.5        1.
#  0.33333333 0.33333333 1.         0.25       0.33333333 0.5
#  1.5        1.         0.33333333 0.2        1.5        1.5
#  0.5        0.2        0.09090909 0.33333333 1.         1.
#  0.25       1.5        0.33333333 0.2        0.25       0.07692308
#  1.5        0.33333333 0.5        1.5        0.16666667 1.5
#  1.         0.2        0.2        0.5        0.25       0.5
#  0.14285714 0.5        1.         1.         1.5        0.14285714
#  0.2        1.5        1.         1.         1.5        0.33333333
#  1.         1.5        1.5        0.5        0.25       0.2
#  0.5        1.5        1.         1.         0.33333333 0.33333333
#  0.2        0.11111111 1.         0.5        1.5        1.5
#  0.33333333 0.5        0.06666667 0.5        0.2        1.5
#  0.25       1.         0.5        0.33333333 1.         0.16666667
#  0.5        0.2        1.         1.5       ]
# ksdjnfsdnfk
# [['switchable', 0.16666666666666666], ['graphic', 0.2], ['card', 0.25], ['pretty', 0.3333333333333333], ['sweet', 0.5], ['want', 1.0], ['gaming', 1.5], ['laptop', 1.0]]
# 8
# [1.5        0.25       1.5        1.         0.25       1.
#  1.         1.         0.5        1.5        0.14285714 0.33333333
#  0.5        0.5        1.5        1.5        1.         0.16666667
#  1.5        0.5        0.25       0.5        0.25       0.33333333
#  1.         0.5        0.08333333 1.         0.33333333 1.5
#  0.125      0.25       0.16666667 0.5        1.         1.
#  1.5        0.33333333 0.5        1.5        1.         0.5
#  1.5        1.         0.33333333 0.25       1.5        1.
#  0.33333333 0.33333333 1.         0.25       1.         0.5
#  1.5        1.         0.33333333 0.2        1.5        1.5
#  0.5        0.2        0.09090909 0.33333333 1.         1.
#  0.25       1.5        0.33333333 0.2        1.5        0.07692308
#  1.5        0.33333333 0.5        1.5        0.16666667 1.5
#  1.         0.2        0.2        0.5        0.25       0.5
#  0.14285714 0.5        1.         1.         1.5        0.14285714
#  0.2        1.5        1.         0.33333333 0.25       0.33333333
#  1.         0.16666667 0.2        0.5        0.25       0.2
#  0.5        1.5        1.         1.         0.33333333 0.33333333
#  0.2        0.11111111 1.         0.5        1.5        1.5
#  0.33333333 0.5        0.06666667 0.5        1.         1.5
#  0.25       1.         0.5        0.33333333 1.         0.16666667
#  0.5        0.2        1.         1.5       ]
# ksdjnfsdnfk
# [['like', 0.3333333333333333], ['least', 0.5], ['hr', 1.0], ['battery', 1.5], ['life', 1.5]]
# 5
# [1.5        0.25       1.5        1.         0.25       1.
#  1.         1.         0.5        1.5        0.14285714 0.33333333
#  0.5        0.5        1.5        1.5        1.         0.16666667
#  1.5        0.5        0.25       0.5        0.25       0.33333333
#  1.         0.5        0.08333333 1.         0.33333333 1.5
#  0.125      0.25       0.16666667 0.5        1.         1.
#  1.5        0.33333333 0.5        1.5        1.         0.5
#  1.5        1.         0.33333333 0.25       1.5        1.
#  0.33333333 0.33333333 1.         0.25       1.         0.5
#  0.5        1.5        1.         0.33333333 0.2        1.5
#  1.5        0.5        0.2        0.09090909 0.33333333 1.
#  0.33333333 0.25       1.5        0.33333333 0.2        1.5
#  0.07692308 1.5        0.33333333 0.5        1.5        0.16666667
#  1.5        1.         0.2        0.2        0.5        0.25
#  0.5        0.14285714 0.5        1.         1.         1.5
#  0.14285714 0.2        1.5        1.         0.33333333 0.25
#  0.33333333 1.         0.16666667 0.2        0.5        0.25
#  0.2        0.5        1.5        1.         1.         0.33333333
#  0.33333333 0.2        0.11111111 1.         0.5        1.5
#  1.5        1.         0.33333333 0.5        0.06666667 0.5
#  1.         1.5        0.25       1.         0.5        0.33333333
#  1.         0.16666667 0.5        0.2        1.         1.5       ]
# ksdjnfsdnfk
# [['good', 1.0], ['speed', 1.5], ['plenty', 1.0], ['hard', 0.5], ['drive', 0.3333333333333333], ['space', 0.25]]
# 6
# [1.5        0.25       1.5        1.         0.25       1.
#  1.         1.         0.5        1.5        0.14285714 0.33333333
#  0.5        0.5        1.5        1.5        1.         0.16666667
#  1.5        0.5        0.25       0.25       0.5        0.25
#  0.33333333 1.         0.5        0.08333333 1.         0.33333333
#  1.5        0.125      0.25       0.16666667 0.5        1.
#  1.         1.5        0.33333333 0.5        1.5        0.33333333
#  0.5        1.5        1.         0.33333333 0.25       1.5
#  1.         0.33333333 0.33333333 1.         0.25       1.
#  0.5        0.5        1.5        1.         0.33333333 0.2
#  1.5        1.5        0.5        0.2        0.09090909 0.33333333
#  1.         0.33333333 0.25       1.5        0.33333333 0.2
#  1.5        0.07692308 1.         1.5        0.33333333 0.5
#  1.5        0.16666667 1.5        1.         0.2        0.2
#  0.5        0.25       0.5        0.14285714 0.5        1.
#  0.5        1.5        0.14285714 0.2        1.5        1.
#  0.33333333 0.25       0.33333333 1.         0.16666667 0.2
#  0.5        0.25       0.2        0.5        1.5        1.
#  1.         0.33333333 0.33333333 0.2        0.11111111 1.
#  0.5        1.5        1.5        1.         0.33333333 0.5
#  0.06666667 0.5        1.         1.5        0.25       1.
#  0.5        0.33333333 1.         0.16666667 0.5        0.2
#  1.         1.5       ]
# ksdjnfsdnfk
# [['good', 0.3333333333333333], ['speed', 0.5], ['plenty', 1.0], ['hard', 1.5], ['drive', 1.5], ['space', 1.5]]
# 6
# [1.5        0.25       1.5        1.         0.25       1.
#  1.         1.         0.5        1.5        0.14285714 0.33333333
#  0.5        0.5        1.5        1.5        1.         0.16666667
#  1.5        0.5        0.25       1.5        0.5        0.25
#  0.33333333 1.         0.5        0.08333333 1.         0.33333333
#  1.5        0.125      0.25       0.16666667 0.5        1.
#  1.         1.5        0.33333333 0.5        1.5        1.5
#  0.5        1.5        1.         0.33333333 0.25       1.5
#  1.         0.33333333 0.33333333 1.         0.25       1.
#  0.5        0.5        1.5        1.         0.33333333 0.2
#  1.5        1.5        0.5        0.2        0.09090909 0.33333333
#  0.33333333 0.33333333 0.25       1.5        0.33333333 0.2
#  1.5        0.07692308 1.         1.5        0.33333333 0.5
#  1.5        0.16666667 1.5        1.         0.2        0.2
#  0.5        0.25       0.5        0.14285714 0.5        1.
#  1.5        1.5        0.14285714 0.2        1.5        1.
#  0.33333333 0.25       0.33333333 1.         0.16666667 0.2
#  0.5        0.25       0.2        0.5        1.5        1.
#  1.         0.33333333 0.33333333 0.2        0.11111111 1.
#  0.5        1.5        1.5        1.         0.33333333 0.5
#  0.06666667 0.5        1.         1.5        0.25       1.
#  0.5        0.33333333 1.         0.16666667 0.5        0.2
#  1.         0.5       ]
# ksdjnfsdnfk
# [['driver', 1.5], ['updates', 1.5], ['not', 1.0], ['fix', 0.5], ['issue', 0.3333333333333333], ['frustrating', 0.25]]
# 6
# [1.5        0.25       1.5        1.         0.25       1.
#  1.         1.         0.5        1.5        0.14285714 0.33333333
#  0.5        0.5        1.5        1.5        1.         0.16666667
#  0.25       1.5        0.5        0.25       1.5        0.5
#  0.25       0.33333333 1.         0.5        0.5        0.08333333
#  1.         0.33333333 1.5        0.125      0.25       0.16666667
#  0.5        1.         1.         1.5        0.33333333 0.5
#  1.5        1.5        1.5        0.5        1.5        1.
#  0.33333333 0.25       1.5        1.         0.33333333 0.33333333
#  1.         0.25       1.         0.33333333 0.5        1.5
#  1.         0.33333333 0.2        1.5        1.5        0.5
#  1.         0.09090909 0.33333333 0.33333333 0.33333333 0.25
#  1.5        0.33333333 0.2        1.5        0.07692308 1.
#  1.5        0.33333333 0.5        1.5        0.16666667 1.5
#  1.         0.2        0.2        0.5        0.25       0.5
#  0.14285714 0.5        1.         1.5        1.5        0.14285714
#  0.2        1.5        1.         0.33333333 0.25       0.33333333
#  1.         0.16666667 0.2        0.5        0.25       0.2
#  0.5        1.5        1.         1.         0.33333333 0.33333333
#  0.2        0.11111111 1.         0.5        1.5        1.5
#  1.         0.33333333 0.5        0.06666667 0.5        1.
#  1.5        0.25       1.         0.5        0.33333333 1.
#  0.16666667 0.5        0.2        1.         0.5       ]
# ksdjnfsdnfk
# [['im', 0.3333333333333333], ['glad', 0.5], ['great', 1.0], ['features', 1.5]]
# 4
# [1.5        0.25       1.5        1.         0.25       1.
#  1.         1.         0.5        1.5        0.14285714 0.33333333
#  0.5        1.         1.5        1.5        1.         0.16666667
#  0.25       1.5        0.5        0.25       1.5        0.5
#  0.25       0.33333333 1.         0.5        0.5        0.08333333
#  1.         0.33333333 1.5        0.125      0.25       0.16666667
#  0.5        1.         1.         0.5        1.5        0.33333333
#  0.5        1.5        1.5        1.5        0.5        1.5
#  1.         0.33333333 0.25       1.5        1.         0.33333333
#  0.33333333 1.         0.25       1.         0.33333333 0.33333333
#  0.5        1.5        1.         0.33333333 0.2        1.5
#  1.5        0.5        1.         0.09090909 0.33333333 0.33333333
#  0.33333333 0.25       1.5        0.33333333 0.2        1.5
#  0.07692308 1.         1.5        0.33333333 0.5        1.5
#  0.16666667 1.5        1.         0.2        0.2        0.5
#  0.25       0.5        0.14285714 0.5        1.         1.5
#  1.5        0.14285714 0.2        1.5        1.         0.33333333
#  0.25       0.33333333 1.         0.16666667 0.2        0.5
#  0.25       0.2        0.5        1.5        1.         1.
#  0.33333333 0.33333333 0.2        0.11111111 1.         0.5
#  1.5        1.5        1.         0.33333333 0.5        0.06666667
#  0.5        1.         1.5        0.25       1.         0.5
#  0.33333333 1.         0.16666667 0.5        0.2        1.
#  0.5       ]
# ksdjnfsdnfk
# [['always', 0.125], ['use', 0.14285714285714285], ['tower', 0.16666666666666666], ['home', 0.2], ['pc', 0.25], ['jump', 0.3333333333333333], ['laptop', 0.5], ['satisfied', 1.0], ['performance', 1.5]]
# 9
# [1.5        0.25       1.5        1.         0.25       1.
#  1.         1.         0.5        1.5        0.14285714 0.33333333
#  0.5        1.         1.5        1.5        1.         0.16666667
#  0.25       1.5        0.5        0.25       1.5        0.5
#  0.25       0.33333333 1.         0.5        0.5        0.08333333
#  1.         0.33333333 1.5        0.125      0.14285714 0.16666667
#  0.5        1.         1.         0.5        1.5        0.33333333
#  0.25       0.5        1.5        1.5        1.5        0.5
#  1.5        1.         0.33333333 0.25       1.         1.5
#  1.         0.33333333 0.33333333 1.         0.25       1.
#  0.33333333 0.33333333 0.16666667 0.5        1.5        1.
#  0.33333333 0.2        1.5        1.5        0.5        1.
#  0.09090909 0.33333333 0.33333333 0.33333333 0.25       1.5
#  0.33333333 0.2        1.5        0.07692308 1.         1.5
#  0.33333333 0.5        1.5        0.16666667 1.5        1.
#  0.2        0.2        0.5        0.25       0.5        0.14285714
#  0.5        1.         1.5        1.5        0.2        0.14285714
#  0.2        1.5        1.         0.33333333 0.25       0.33333333
#  1.         0.16666667 0.2        0.5        0.25       0.2
#  0.5        0.125      1.5        1.         1.         0.33333333
#  0.33333333 0.2        0.11111111 1.         0.5        1.5
#  1.5        1.         0.33333333 0.5        0.06666667 0.5
#  0.5        1.5        0.25       1.         0.5        0.33333333
#  1.         0.33333333 0.16666667 0.5        0.2        1.
#  0.5       ]
# ksdjnfsdnfk
# [['sister', 0.25], ['mac', 0.3333333333333333], ['band', 0.5], ['use', 1.0], ['garageband', 1.5], ['record', 1.0], ['edit', 0.5]]
# 7
# [1.5        0.25       1.5        1.         0.25       1.
#  1.         1.         0.5        0.25       1.5        0.14285714
#  0.33333333 1.         0.5        1.         1.5        1.5
#  1.         0.16666667 0.25       1.5        0.5        0.25
#  1.5        0.5        0.5        0.25       0.33333333 1.
#  0.5        0.5        0.08333333 1.         0.33333333 1.5
#  0.125      1.5        1.         0.16666667 0.5        1.
#  1.         0.5        1.5        0.33333333 0.25       0.5
#  1.5        1.5        1.5        0.5        1.5        1.
#  0.33333333 0.25       1.         1.5        1.         0.33333333
#  0.33333333 1.         0.25       1.         0.33333333 0.33333333
#  0.33333333 0.16666667 0.5        1.5        1.         0.33333333
#  0.2        1.5        1.5        0.5        1.         0.09090909
#  0.33333333 0.33333333 0.33333333 0.25       1.5        0.33333333
#  0.2        1.5        0.07692308 1.         1.5        0.33333333
#  0.5        1.5        0.16666667 1.5        1.         0.2
#  0.2        0.5        0.25       0.5        0.14285714 0.5
#  1.         1.5        1.5        0.2        0.14285714 0.2
#  1.5        1.         0.33333333 0.25       0.33333333 1.
#  0.16666667 0.2        0.5        0.25       0.2        0.5
#  0.125      1.5        1.         1.         0.33333333 0.33333333
#  0.2        0.11111111 1.         0.5        0.5        1.5
#  1.5        1.         0.33333333 0.5        0.06666667 0.5
#  0.5        1.5        0.25       1.         0.5        0.33333333
#  1.         0.33333333 0.16666667 0.5        0.2        1.
#  0.5       ]
# ksdjnfsdnfk
# [['look', 0.07692307692307693], ['sexyy', 0.08333333333333333], ['really', 0.09090909090909091], ['mac', 0.1], ['book', 0.1111111111111111], ['pro', 0.125], ['best', 0.14285714285714285], ['laptop', 0.16666666666666666], ['specially', 0.2], ['student', 0.25], ['college', 0.3333333333333333], ['not', 0.5], ['care', 1.0], ['price', 1.5]]
# 14
# [1.5        0.25       1.5        1.         0.25       1.
#  1.         1.         0.5        0.25       1.5        0.14285714
#  0.33333333 1.         0.5        1.         1.5        1.5
#  1.         0.16666667 0.25       1.5        0.5        0.25
#  1.5        0.5        0.5        0.09090909 0.33333333 1.
#  0.5        0.5        0.08333333 1.         0.33333333 0.33333333
#  0.07692308 1.5        0.125      1.5        1.         0.16666667
#  0.5        1.         1.         0.5        1.5        0.33333333
#  0.25       0.5        1.5        1.5        1.5        0.5
#  0.11111111 1.5        1.         0.33333333 0.25       1.
#  1.5        0.14285714 1.         0.33333333 0.33333333 1.
#  0.25       0.2        1.         0.25       0.33333333 0.33333333
#  0.1        0.16666667 0.08333333 0.5        1.5        1.
#  0.33333333 0.2        1.5        1.5        0.5        0.5
#  0.09090909 0.33333333 0.33333333 0.33333333 0.25       1.5
#  0.33333333 0.2        1.5        0.125      1.         1.5
#  0.33333333 0.5        1.5        0.16666667 1.5        1.
#  1.         0.2        0.5        0.25       0.5        0.14285714
#  0.5        1.         1.5        1.5        0.2        0.14285714
#  0.2        1.5        1.         0.33333333 0.25       0.33333333
#  1.         0.16666667 0.2        0.5        0.25       0.2
#  0.5        0.125      1.5        1.         1.         0.33333333
#  0.33333333 0.2        0.11111111 1.         0.5        0.5
#  1.5        1.5        1.         0.33333333 0.5        0.06666667
#  0.5        0.16666667 1.5        0.25       1.         0.5
#  0.33333333 1.         0.33333333 0.16666667 0.5        0.2
#  1.         0.5       ]
# ksdjnfsdnfk
# [['also', 1.0], ['extended', 1.5], ['warranty', 1.5], ['problem', 1.0]]
# 4
# [1.5        0.25       1.5        1.         0.25       1.
#  1.         1.         0.5        0.25       1.5        0.14285714
#  0.33333333 1.         0.5        1.         1.5        1.5
#  1.         0.16666667 0.25       1.5        0.5        0.25
#  1.5        0.5        0.5        1.5        0.09090909 0.33333333
#  1.         0.5        0.5        1.         0.08333333 1.
#  0.33333333 0.33333333 0.07692308 1.5        1.         0.125
#  1.5        1.         0.16666667 0.5        1.         1.
#  0.5        1.5        0.33333333 0.25       0.5        1.5
#  1.5        1.5        0.5        0.11111111 1.5        1.
#  0.33333333 0.25       1.         1.5        0.14285714 1.
#  1.5        0.33333333 0.33333333 1.         0.25       0.2
#  1.         0.25       0.33333333 0.33333333 0.1        0.16666667
#  0.08333333 0.5        1.5        1.         0.33333333 0.2
#  1.5        1.5        0.5        0.5        0.09090909 0.33333333
#  0.33333333 0.33333333 0.25       1.5        0.33333333 0.2
#  1.5        0.125      1.         1.5        0.33333333 0.5
#  1.5        0.16666667 1.5        1.         1.         0.2
#  0.5        0.25       0.5        0.14285714 0.5        1.
#  1.5        1.5        0.2        0.14285714 0.2        1.5
#  1.         0.33333333 0.25       0.33333333 1.         0.16666667
#  0.2        0.5        0.25       0.2        0.5        0.125
#  1.5        1.         1.         0.33333333 0.33333333 0.2
#  0.11111111 1.         0.5        0.5        1.5        1.5
#  1.         0.33333333 0.5        0.06666667 0.5        0.16666667
#  1.5        0.25       1.         0.5        0.33333333 1.
#  0.33333333 0.16666667 0.5        0.2        1.         0.5       ]
# ksdjnfsdnfk
# [['opinion', 0.125], ['sony', 0.14285714285714285], ['drop', 0.16666666666666666], ['fast', 0.2], ['stock', 0.25], ['market', 0.3333333333333333], ['give', 0.5], ['horrible', 1.0], ['support', 1.5], ['but', 1.0], ['machine', 0.5], ['cause', 0.3333333333333333], ['plunge', 0.25]]
# 13
# [1.5        0.25       1.5        1.         0.25       1.
#  1.         1.         0.5        0.25       1.5        0.14285714
#  0.33333333 1.         0.5        1.         1.5        1.5
#  1.         0.16666667 0.25       1.5        0.5        0.14285714
#  0.16666667 0.25       1.5        0.5        0.5        1.5
#  0.09090909 0.33333333 1.         1.         0.5        0.5
#  1.         0.08333333 1.         0.33333333 0.33333333 0.07692308
#  1.5        1.         1.         1.5        1.         0.16666667
#  0.5        1.         0.25       1.         0.5        1.5
#  0.33333333 0.25       0.5        1.5        1.5        1.5
#  0.5        0.11111111 1.5        1.         0.33333333 0.25
#  1.         1.5        0.14285714 1.         1.5        0.33333333
#  0.33333333 1.         0.25       0.2        1.         0.25
#  0.33333333 0.33333333 0.1        0.16666667 0.08333333 0.5
#  1.5        1.         0.33333333 0.2        1.5        1.5
#  0.5        0.5        0.09090909 0.33333333 0.33333333 0.33333333
#  0.25       1.5        0.33333333 0.2        1.5        0.125
#  1.         1.5        0.33333333 0.5        1.5        0.16666667
#  1.5        1.         1.         0.2        0.33333333 0.5
#  0.25       0.5        0.14285714 0.5        0.2        1.5
#  1.5        0.2        0.14285714 0.2        1.5        1.
#  0.33333333 0.25       0.33333333 1.         0.16666667 0.2
#  0.5        0.25       0.2        0.5        0.125      1.5
#  0.125      1.         1.         0.33333333 0.33333333 0.2
#  0.11111111 1.         0.5        0.5        1.5        1.5
#  1.         0.33333333 0.5        0.06666667 0.5        0.16666667
#  0.5        1.5        0.33333333 0.25       1.         0.5
#  0.33333333 1.         0.33333333 0.5        0.16666667 0.5
#  0.25       0.2        1.         0.5       ]
# ksdjnfsdnfk
# [['also', 0.5], ['like', 1.0], ['glass', 1.5], ['screen', 1.5]]
# 4
# [1.5        0.25       1.5        1.         0.25       1.
#  1.         1.         0.5        0.25       1.5        0.14285714
#  0.33333333 1.         0.5        1.         1.5        1.5
#  1.         0.16666667 0.25       1.5        0.5        0.14285714
#  0.16666667 0.25       1.5        0.5        0.5        1.5
#  0.09090909 0.33333333 1.         1.         0.5        0.5
#  0.5        0.08333333 1.         0.33333333 0.33333333 0.07692308
#  1.5        1.         1.         1.5        1.         0.16666667
#  0.5        1.         0.25       1.         0.5        1.5
#  0.33333333 0.25       0.5        1.5        1.5        1.5
#  0.5        0.11111111 1.5        1.         0.33333333 0.25
#  1.         1.5        0.14285714 1.         1.5        0.33333333
#  0.33333333 1.         0.25       0.2        1.         0.25
#  0.33333333 0.33333333 0.1        0.16666667 0.08333333 0.5
#  1.5        1.         0.33333333 0.2        1.5        1.5
#  0.5        0.5        0.09090909 0.33333333 0.33333333 1.
#  0.25       1.5        0.33333333 0.2        1.5        0.125
#  1.         1.5        0.33333333 0.5        1.5        0.16666667
#  1.5        1.         1.         0.2        1.5        0.33333333
#  0.5        0.25       0.5        0.14285714 0.5        0.2
#  1.5        1.5        0.2        0.14285714 0.2        1.5
#  1.         0.33333333 0.25       0.33333333 1.         0.16666667
#  0.2        0.5        0.25       0.2        0.5        0.125
#  1.5        0.125      1.         1.         0.33333333 0.33333333
#  0.2        0.11111111 1.         0.5        0.5        1.5
#  1.5        1.         0.33333333 0.5        0.06666667 0.5
#  0.16666667 0.5        1.5        0.33333333 0.25       1.
#  0.5        0.33333333 1.         0.33333333 0.5        0.16666667
#  0.5        0.25       0.2        1.         0.5       ]
# ksdjnfsdnfk
# [['call', 0.25], ['toshiba', 0.09090909090909091], ['not', 0.5], ['anything', 0.1111111111111111], ['even', 0.3333333333333333], ['try', 0.14285714285714285], ['charge', 0.16666666666666666], ['phone', 0.2], ['offer', 1.0], ['technical', 1.5], ['support', 1.5]]
# 11
# [1.5        0.25       1.5        1.         0.25       1.
#  1.         1.         0.5        0.25       1.5        0.14285714
#  0.33333333 1.         0.5        1.         1.5        1.5
#  1.         0.33333333 0.25       1.5        0.5        0.14285714
#  0.16666667 0.25       1.5        0.5        0.5        1.5
#  0.09090909 0.33333333 1.         1.         0.5        0.5
#  0.5        0.08333333 1.         0.33333333 0.33333333 0.07692308
#  1.5        1.         1.         1.5        1.         0.16666667
#  0.5        1.         0.25       1.         0.5        1.5
#  0.33333333 0.25       0.5        1.5        1.5        1.5
#  0.5        0.11111111 1.5        1.         0.33333333 0.25
#  1.         1.5        0.14285714 1.         1.5        0.33333333
#  0.11111111 0.33333333 1.         0.25       0.2        1.
#  0.25       0.33333333 0.33333333 0.1        0.16666667 0.08333333
#  0.5        1.5        1.         0.33333333 0.2        1.5
#  1.5        0.5        0.5        0.09090909 0.33333333 0.33333333
#  1.         0.25       1.5        0.33333333 1.         0.2
#  1.5        0.125      1.         1.5        0.33333333 0.5
#  1.5        0.16666667 1.5        1.         1.         0.2
#  1.5        0.33333333 0.09090909 0.25       0.5        0.14285714
#  0.5        0.2        1.5        1.5        0.2        0.14285714
#  0.2        1.5        1.         0.33333333 0.25       0.33333333
#  1.         0.16666667 0.2        0.5        0.25       0.2
#  0.5        0.125      1.5        0.125      1.         1.
#  0.33333333 0.33333333 0.2        0.11111111 1.         0.5
#  0.14285714 0.5        1.5        1.5        1.         0.33333333
#  0.5        0.06666667 0.5        0.16666667 0.5        1.5
#  0.2        0.33333333 0.25       1.         0.5        0.33333333
#  1.         0.33333333 0.5        0.16666667 0.5        0.25
#  0.16666667 0.2        1.         0.5       ]
# ksdjnfsdnfk
# [['beware', 1.0], ['staff', 1.5], ['send', 1.0], ['back', 0.5], ['make', 0.3333333333333333], ['feel', 0.25], ['know', 0.2], ['computer', 0.16666666666666666]]
# 8
# [1.5        0.25       0.25       1.5        1.         0.25
#  1.         1.         1.         0.5        0.25       0.2
#  1.5        0.14285714 0.33333333 1.         0.5        1.
#  1.5        1.5        1.         0.33333333 0.25       1.5
#  0.5        0.14285714 0.16666667 0.25       1.5        0.5
#  0.5        1.5        0.09090909 0.33333333 1.         1.
#  0.5        0.5        0.5        0.08333333 1.         0.33333333
#  0.33333333 0.07692308 1.5        1.         1.         1.5
#  1.         0.16666667 0.5        1.         0.25       1.
#  0.5        1.5        0.33333333 0.25       0.5        1.5
#  1.5        1.5        0.5        0.11111111 1.5        1.
#  0.33333333 0.25       1.         1.5        0.14285714 1.
#  1.5        0.33333333 0.11111111 0.33333333 1.         0.25
#  0.2        1.         0.25       0.33333333 0.33333333 0.1
#  0.16666667 0.08333333 0.5        1.5        1.         1.
#  0.33333333 0.5        1.5        1.5        0.5        0.5
#  0.09090909 0.33333333 0.33333333 1.         0.25       1.5
#  0.33333333 1.         0.2        1.5        1.5        0.125
#  1.         1.5        0.33333333 0.5        1.5        0.16666667
#  1.5        1.         1.         0.2        1.5        0.33333333
#  0.09090909 0.25       0.5        0.14285714 0.5        0.2
#  1.5        1.5        0.2        0.14285714 0.2        1.5
#  1.         0.33333333 0.25       0.33333333 1.         0.16666667
#  0.2        0.5        0.25       0.2        0.5        0.125
#  1.5        0.125      0.16666667 1.         0.33333333 0.33333333
#  0.2        0.11111111 1.         0.5        0.14285714 0.5
#  1.5        1.5        1.         0.33333333 0.5        0.06666667
#  0.5        0.16666667 0.5        1.         1.5        0.2
#  0.33333333 0.25       1.         0.5        0.33333333 1.
#  0.33333333 0.5        0.16666667 0.5        0.25       0.16666667
#  0.2        1.         0.5       ]
# ksdjnfsdnfk
# [['thing', 0.2], ['not', 0.25], ['like', 0.3333333333333333], ['mac', 0.5], ['sometimes', 1.0], ['programs', 1.5], ['want', 1.0], ['able', 0.5], ['run', 0.3333333333333333]]
# 9
# [1.5        0.25       0.25       1.5        1.         0.25
#  1.         1.         1.         0.5        0.25       0.2
#  1.5        0.14285714 0.33333333 1.         0.5        1.
#  1.5        1.5        1.         0.33333333 0.25       1.5
#  0.5        0.14285714 1.         0.16666667 0.25       1.5
#  0.5        0.5        1.5        0.09090909 0.2        1.
#  1.         0.5        0.5        0.5        0.08333333 1.
#  0.33333333 0.33333333 0.07692308 1.5        1.         1.
#  1.5        1.         0.16666667 0.5        1.         0.25
#  1.         0.5        1.5        0.33333333 0.25       0.5
#  1.5        1.5        1.5        0.5        0.11111111 1.5
#  1.         0.33333333 0.25       1.         1.5        0.14285714
#  1.         1.5        0.33333333 0.11111111 0.33333333 1.
#  0.25       0.2        1.         0.25       0.33333333 0.33333333
#  0.5        0.16666667 1.5        0.08333333 0.5        1.5
#  1.         1.         0.33333333 0.5        1.5        1.5
#  0.5        0.25       0.09090909 0.33333333 0.33333333 0.33333333
#  0.25       1.5        0.33333333 1.         0.2        1.5
#  1.5        0.125      1.         1.5        0.33333333 0.5
#  1.5        0.16666667 1.5        1.         1.         0.2
#  1.5        0.33333333 0.09090909 0.25       0.5        0.14285714
#  0.5        0.2        1.5        1.5        0.2        0.14285714
#  0.2        1.5        1.         0.33333333 0.25       0.33333333
#  1.         0.16666667 0.2        0.5        0.25       0.2
#  0.5        0.5        0.125      1.5        0.125      0.16666667
#  1.         0.33333333 0.33333333 0.2        0.11111111 1.
#  0.5        0.14285714 0.5        1.5        1.5        1.
#  0.33333333 0.5        0.06666667 0.5        0.16666667 0.5
#  1.         1.5        0.2        0.33333333 0.25       1.
#  0.33333333 0.33333333 1.         0.33333333 0.5        0.16666667
#  0.5        0.25       0.16666667 0.2        1.         0.5       ]
# ksdjnfsdnfk
# [['wireless', 1.5], ['not', 1.0], ['issue', 0.5], ['others', 0.3333333333333333], ['meantioned', 0.25]]
# 5
# [1.5        0.25       0.25       1.5        1.         0.25
#  1.         1.         1.         0.5        0.25       0.2
#  1.5        0.14285714 0.33333333 1.         0.5        1.
#  1.5        1.5        1.         0.33333333 0.25       1.5
#  0.5        0.14285714 1.         0.16666667 0.25       1.5
#  0.5        0.5        1.5        0.09090909 0.2        1.
#  1.         0.5        0.5        0.5        0.08333333 1.
#  0.33333333 0.33333333 0.07692308 1.5        0.33333333 1.
#  1.         1.5        1.         0.16666667 0.5        1.
#  0.25       1.         0.5        1.5        0.33333333 0.25
#  0.5        1.5        1.5        1.5        0.5        0.11111111
#  1.5        1.         0.33333333 0.25       1.         1.5
#  0.14285714 1.         1.5        0.33333333 0.11111111 0.33333333
#  1.         0.25       0.2        1.         0.25       0.5
#  0.33333333 0.5        0.16666667 1.5        0.08333333 0.5
#  1.5        1.         1.         0.33333333 0.5        1.5
#  1.5        0.5        1.         0.25       0.09090909 0.33333333
#  0.33333333 0.33333333 0.25       1.5        0.33333333 1.
#  0.2        1.5        1.5        0.125      1.         1.5
#  0.33333333 0.5        1.5        0.16666667 1.5        1.
#  1.         0.2        1.5        0.33333333 0.09090909 0.25
#  0.5        0.14285714 0.5        0.2        1.5        1.5
#  0.2        0.14285714 0.2        1.5        1.         0.33333333
#  0.25       0.33333333 1.         0.16666667 0.2        0.5
#  0.25       0.2        0.5        0.5        0.125      1.5
#  0.125      0.16666667 1.         0.33333333 0.33333333 0.2
#  1.5        0.11111111 1.         0.5        0.14285714 0.5
#  1.5        1.5        1.         0.33333333 0.5        0.06666667
#  0.5        0.16666667 0.5        1.         1.5        0.2
#  0.33333333 0.25       1.         0.33333333 0.33333333 1.
#  0.33333333 0.5        0.16666667 0.5        0.25       0.16666667
#  0.2        1.         0.5       ]
# ksdjnfsdnfk
# [['macbook', 0.2], ['notebooks', 0.25], ['quickly', 0.3333333333333333], ['die', 0.5], ['short', 1.0], ['battery', 1.5], ['life', 1.5], ['well', 1.0], ['many', 0.5], ['background', 0.3333333333333333], ['program', 0.25], ['run', 0.2], ['user', 0.16666666666666666], ['knowlede', 0.14285714285714285]]
# 14
# [1.5        0.25       0.25       1.5        1.         0.25
#  0.25       1.         1.         1.         0.5        0.25
#  0.2        1.5        0.14285714 0.33333333 1.         0.5
#  1.         1.5        1.5        1.         0.33333333 0.25
#  1.5        0.5        0.14285714 1.         0.16666667 0.25
#  1.5        0.5        0.5        1.5        0.09090909 0.2
#  1.         1.         0.5        0.5        0.5        0.5
#  0.08333333 1.         0.33333333 0.33333333 0.07692308 1.5
#  0.33333333 1.         1.         1.5        1.         0.33333333
#  0.16666667 0.5        1.         0.25       1.         0.5
#  0.5        1.5        0.33333333 0.25       0.5        1.5
#  1.5        1.5        0.5        0.11111111 1.5        1.
#  0.33333333 0.25       1.         1.5        0.14285714 1.
#  1.5        0.33333333 0.11111111 0.33333333 1.         0.33333333
#  0.25       0.2        1.         0.25       0.5        0.33333333
#  0.5        0.16666667 1.5        0.08333333 0.5        1.5
#  1.         1.         0.33333333 0.5        1.5        1.5
#  0.5        1.         0.25       0.09090909 0.33333333 0.33333333
#  0.33333333 1.         1.5        0.33333333 1.         0.2
#  1.5        1.5        0.125      1.         1.5        0.33333333
#  0.5        1.5        0.16666667 0.14285714 1.5        1.
#  1.         0.2        1.5        0.33333333 0.09090909 0.25
#  0.5        0.14285714 0.5        0.2        1.5        1.5
#  0.2        0.2        0.2        1.5        1.         0.33333333
#  0.25       0.33333333 1.         0.16666667 0.2        0.5
#  0.25       0.2        0.5        0.5        0.125      1.5
#  0.16666667 0.125      0.16666667 1.         1.         0.33333333
#  0.25       0.33333333 0.2        1.5        0.11111111 1.
#  0.5        0.14285714 0.5        1.5        1.5        1.
#  0.33333333 0.5        0.06666667 0.5        0.16666667 0.5
#  1.         1.5        0.2        0.33333333 0.25       1.
#  0.2        0.33333333 1.         0.33333333 0.5        0.16666667
#  0.5        0.25       0.16666667 0.2        1.         0.5       ]
# ksdjnfsdnfk
# [['macbook', 0.1111111111111111], ['notebooks', 0.125], ['quickly', 0.14285714285714285], ['die', 0.16666666666666666], ['short', 0.2], ['battery', 0.25], ['life', 0.3333333333333333], ['well', 0.5], ['many', 1.0], ['background', 1.5], ['programs', 1.5], ['run', 1.0], ['user', 0.5], ['knowlede', 0.3333333333333333]]
# 14
# [1.5        0.25       0.25       1.5        1.         0.125
#  0.25       1.         1.         1.         0.5        0.25
#  0.2        1.5        0.14285714 0.33333333 1.         0.5
#  1.         1.5        1.5        1.         0.33333333 0.25
#  1.5        0.5        0.14285714 1.         0.16666667 0.25
#  1.5        0.5        0.5        1.5        0.09090909 0.2
#  1.         1.         0.5        0.16666667 0.5        0.5
#  0.08333333 1.         0.33333333 0.33333333 0.07692308 1.5
#  0.33333333 1.         1.         1.5        1.         0.14285714
#  0.16666667 0.5        1.         0.25       1.         1.
#  0.5        1.5        0.33333333 0.25       0.5        1.5
#  1.5        1.5        0.5        0.11111111 1.5        1.
#  0.33333333 0.25       1.         1.5        0.14285714 1.
#  1.5        0.33333333 0.11111111 0.33333333 1.         1.5
#  0.25       0.2        1.         0.25       0.5        0.33333333
#  0.5        0.16666667 1.5        0.08333333 0.5        0.33333333
#  1.         1.         0.33333333 0.5        1.5        1.5
#  0.5        1.         0.25       0.09090909 0.33333333 0.33333333
#  0.33333333 0.5        0.25       0.33333333 1.         0.2
#  1.5        1.5        0.125      1.         1.5        0.33333333
#  0.5        1.5        0.16666667 0.33333333 1.5        1.
#  1.         0.2        1.5        0.33333333 0.09090909 0.25
#  0.5        0.14285714 0.5        0.2        1.5        1.5
#  0.2        0.11111111 0.2        1.5        1.         0.33333333
#  0.25       0.33333333 1.         0.16666667 0.2        0.5
#  0.25       0.2        0.5        0.5        0.125      1.5
#  0.5        0.125      0.16666667 1.         0.2        0.33333333
#  0.25       0.33333333 0.2        1.5        0.11111111 1.
#  0.5        0.14285714 0.5        1.5        1.5        1.
#  0.33333333 0.5        0.06666667 0.5        0.16666667 0.5
#  1.         1.5        0.2        0.33333333 0.25       1.
#  1.         0.33333333 1.         0.33333333 0.5        0.16666667
#  0.5        0.25       0.16666667 0.2        1.         0.5       ]
# ksdjnfsdnfk
# [['great', 1.0], ['price', 1.5]]
# 2
# [1.5        0.25       0.25       1.5        1.         0.125
#  0.25       1.         1.         1.         0.5        0.25
#  0.2        1.5        0.14285714 0.33333333 1.         0.5
#  1.         1.5        1.5        1.         0.33333333 0.25
#  1.5        0.5        0.14285714 1.         0.16666667 0.25
#  1.5        0.5        0.5        1.5        0.09090909 0.2
#  1.         1.         0.5        0.16666667 0.5        0.5
#  0.08333333 1.         0.33333333 0.33333333 0.07692308 1.5
#  0.33333333 1.         1.         1.5        1.         0.14285714
#  0.16666667 0.5        1.         0.25       1.         1.
#  0.5        1.5        0.33333333 0.25       0.5        1.5
#  1.5        1.5        0.5        0.11111111 1.5        1.
#  0.33333333 0.25       1.         1.5        0.14285714 1.
#  1.5        0.33333333 0.11111111 0.33333333 1.         1.5
#  0.25       0.2        1.         0.25       0.5        0.33333333
#  0.5        0.16666667 1.5        0.08333333 0.5        0.33333333
#  1.         1.         0.33333333 0.5        1.5        1.5
#  0.5        1.         0.25       0.09090909 0.33333333 0.33333333
#  0.33333333 0.5        0.25       0.33333333 1.         0.2
#  1.5        1.5        0.125      1.         1.5        0.33333333
#  0.5        1.5        0.16666667 0.33333333 1.5        1.
#  1.         0.2        1.5        0.33333333 0.09090909 0.25
#  0.5        0.14285714 0.5        0.2        1.5        1.5
#  0.2        0.11111111 0.2        1.5        1.         0.33333333
#  0.25       0.33333333 1.         0.16666667 0.2        0.5
#  0.25       0.2        0.5        0.5        0.125      1.5
#  0.5        0.125      0.16666667 1.         0.2        0.33333333
#  0.25       0.33333333 0.2        1.5        0.11111111 1.
#  0.5        0.14285714 0.5        1.5        1.5        1.
#  0.33333333 0.5        0.06666667 0.5        0.16666667 0.5
#  1.         1.5        0.2        0.33333333 0.25       1.
#  1.         0.33333333 1.         0.33333333 0.5        0.16666667
#  0.5        0.25       0.16666667 0.2        1.         0.5       ]
# ksdjnfsdnfk

# %%
pf.close()

# %%
test_weight_x = np.array(test_weight_x)

print(test_weight_x.shape)
# Out:
# (49, 2429)

# %%
nlp.close()
