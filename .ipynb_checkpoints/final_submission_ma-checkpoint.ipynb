# %%
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import word_tokenize
import numpy as np
import string
import re
from functools import reduce

stopwords_set = set(stopwords.words('english'))
stopwords_set = {'i', 'shan', 'just', 'how', 'each', 'out', 'themselves', 'their', 'before', 'were', 'very', 'as', 'further', 'his', 'a', 'once', 'youve', 'y', 'is', 'shouldve', 'youll', 'on', 'd', 'm', 'under', 'haven', 'which', 'only', 'them', 'was', 'by', 'needn', 'whom', 'that', 'when', 's', 'isn', 'its', 'wasn', 'in', 'we', 'theirs', 'those', 'this', 'having', 'and', 'ain', 'most', 'up', 'off', 'being', 'aren', 'shouldn', 'ourselves', 'from', 'down', 'herself', 'her', 'you', 'are', 'its', 'who', 'the', 'here', 'where', 'your', 'youd', 'she', 'didn', 'weren', 'about', 'has', 'our', 'an', 'yourselves', 'or', 'hasn', 'again', 'while', 'does', 'him', 'shes', 'above', 'below', 'itself', 'to', 'through', 'will', 'couldn', 'hers', 'they', 'doing', 'because', 'he', 'what', 'such', 'youre', 'too', 'should', 'ours', 'then', 'himself', 'all', 'of', 'mightn', 'between', 'now', 'against', 'some', 'with', 'until', 'am', 'other', 'at', 'can', 'over', 'mustn', 'wouldn', 'do', 'for', 'after', 'hadn', 'me', 'been', 'same', 'doesn', 'my', 'these', 'll', 'did', 'had', 'it', 'so', 'ma', 'during', 'than', 'o', 'yourself', 'own', 'have', 're', 've', 'be', 'why', 't', 'there', 'more', 'won', 'yours', 'few', 'into', 'thatll', 'any', 'myself', 'both', 'don', 'if'}

# %%
fname = 'project_2_train/' + 'data 2_train.csv'

# %%
sentence_weights = []
X, Y, X1 = [], [], []

# %%
f = open(fname, 'r')

# %%
for i, line in enumerate(f):
    if i != 0:
        ''' Splitting the columns based on comma - since it is csv'''
        columns = line.split(',')

        ''' The comma in the actual sentence was represented as [commma] because of csv format, replace that '''
        columns[1] = columns[1].replace('[comma]', ',')
        columns[2] = columns[2].replace('[comma]', ',')

        ''' Some aspect terms are mic in the sentence where computer/mic is present '''
        columns[1] = columns[1].replace('-', ' ')
        columns[2] = columns[2].replace('-', ' ')
        columns[1] = columns[1].replace('/', ' ')
        columns[2] = columns[2].replace('/', ' ')

        ''' NOt used anymore'''
        tokenizer = RegexpTokenizer(r'\w+') # doesn't work if the special char is in the token
        # columns[2] = tokenizer.tokenize(columns[2].lower())

        '''Tokenize the words'''
        columns[1] = word_tokenize(columns[1])
        columns[2] = word_tokenize(columns[2])

        for j, elem in enumerate(columns[1]):
            '''Remove special characters'''
            columns[1][j] = re.sub('[^0-9a-zA-Z]+', '', elem).lower()
            ''' didn't is tokenized as did n't hence following code '''
            if columns[1][j] == 'nt':
                columns[1][j] = 'not'

        for j, elem in enumerate(columns[2]):
            '''Remove special characters'''
            columns[2][j] = re.sub('[^0-9a-zA-Z]+', '', elem).lower()
            ''' didn't is tokenized as did n't hence following code '''
            if columns[2][j] == 'nt':
                columns[2][j] = 'not'

        '''Remove empty string tokens'''
        columns[1] = [x.strip() for x in columns[1] if x.strip() != '']
        columns[2] = [x.strip() for x in columns[2] if x.strip() != '']

        ''' Remove stop words '''
        columns[1] = [word for word in columns[1] if word not in stopwords_set]
        columns[1] = [word for word in columns[1] if word not in stopwords_set]
        columns[2] = [word for word in columns[2] if word not in stopwords_set]

        columns[1] = ' '.join(columns[1])
        columns[2] = ' '.join(columns[2])

        ''' The aspect term location given is not proper - hence extracting the location by ourselves '''
        columns[3] = []
        ''' Finds the location of the aspect term in the sentence '''
        for m in re.finditer(columns[2], columns[1]):
            columns[3].append([m.start(), m.end()])
            ''' since some aspect terms are not surrounded by spaces, hence below code
            NOT USED ANYMORE
            '''
            if m.start() != 0 and columns[1][m.start() - 1] != ' ':
                # columns[1] = columns[1][:m.start()] + ' ' + columns[1][m.start():]
                pass

        ''' Because of adding space in above code, the position is messed up, hence redoing it. '''
        columns[3] = []

        for m in re.finditer(columns[2], columns[1]):
            columns[3].append([m.start(), m.end()])

        ''' Tokenizing the words again '''
        columns[1] = columns[1].split(' ')
        columns[2] = columns[2].split(' ')
        ''' New column to specify the aspect term location in the list '''
        columns.append([])
        # columns[5] = []
        ''' for multiple positions of aspect term '''
        for elem in columns[3]:
            if elem[0] == 0: #start index of the 1st occurance of the aspect term
                columns[5].append([0])
            else:
                temp_len = elem[0] # assign the start position of the aspect term
                for j, tokens in enumerate(columns[1]):
                    temp_len -= (len(tokens) + 1) # Counting the words till the position - +1 for blank space
                    if temp_len == 0: # Reached the aspect word
                        columns[5].append([j+1])
                        break
            for k in range(len(columns[2])-1): # if multiple words in the aspect term - tag the following words in the sentence
                columns[5][-1].append(columns[5][-1][-1]+1)

        ''' if not found the aspect term location in the list then do '''
        if len(columns[5]) < 1:
            continue

            # pass

        word_wt_list = [[elem, 0] for elem in columns[1]]
        ''' Assigning weights to every word based on the distance from the aspect term '''
        for j, elem in enumerate(columns[5]):
            for k, word in enumerate(columns[1]):
                if k < elem[0]: # Word left to the aspect term
                    dist = abs(elem[0] - k)
                    if word_wt_list[k][1] < 1/dist:
                        word_wt_list[k][1] = 1/dist
                elif k > elem[-1]: # word right to the aspect term : Aspect term can have multiple words
                    dist = abs(k - elem[-1])
                    if word_wt_list[k][1] < 1/dist:
                        word_wt_list[k][1] = 1/dist
            for aspect_word_loc in elem:
                word_wt_list[aspect_word_loc][1] = 1.5

        ''' For duplicate words - if it's aspect term - add the weights, if not, then take the weight which is greater, make the other weight as zero '''
        for j, word_1 in enumerate(word_wt_list):
            for k, word_2 in enumerate(word_wt_list[j+1:]):
                if word_1[0] == word_2[0]:
                    if word_1[1] == 1.5 and word_2[1] == 1.5:
                        # print(line)
                        # print(word_wt_list)
                        word_1[1] += 1.5
                        word_2[1] = 0
                    elif word_1[1] < word_2[1]:
                        # print(line)
                        # print(word_wt_list)
                        word_1[1] = word_2[1]
                        word_2[1] = 0
                    elif word_1[1] > word_2[1]:
                        # print(line)
                        # print(word_wt_list)
                        word_2[1] = 0
                    elif word_1[1] == word_2[1]:
                        word_2[1] = 0


        ''' For removing duplicate words - they have weight zero now'''
        word_wt_list = [elem for elem in word_wt_list if elem[1] != 0]

        if len(columns[2]) > 1 and len(columns[5]) > 1:
            # print(line)
            # print(columns)
            # print(word_wt_list)
            pass

        if columns[0] == '2911_0':
            # print(line)
            # print(word_wt_list)
            pass
        if i == 100:
            # break
            pass

        '''Removing new line character from columns[4] -  the polarity column'''
#         columns[4] = columns[4].rstrip('\n')
        X.append(columns[1])
        X1.append(' '.join(columns[1]))

        Y.append(columns[4])
        sentence_weights.append(word_wt_list)

'success'
# Out:
# 'success'

# %%
'''Building vocabulary and counting word occurances'''
X_reduced = reduce(lambda x1, x2: x1 + x2, X)
vocab = list(set(X_reduced))
print(vocab[0])
weight_v = np.zeros_like(vocab, dtype = np.float_)
weight_x = []
# Out:
# self

# %%
pf = open('weightxy_data2.csv', 'w')

pf.write(','.join(vocab))
pf.write(',class_')
pf.write('\n')
# Out:
# 1

# %%
for i, sentence in enumerate(sentence_weights):
    for word in sentence:
        v_index = vocab.index(word[0])
        weight_v[v_index] = word[1]

    weight_x.append(weight_v)
    if len(sentence) != weight_v[np.where(weight_v > 0)].shape[0]:
        print(sentence)
        print(len(sentence))
        print(weight_v[np.where(weight_v > 0)])

    ''' code to write the data to file '''
    temp = [str(j) for j in weight_v.tolist()]
    pf.write(','.join(temp))
    pf.write(','+str(Y[i]))
    pf.write('\n')
    weight_v = np.zeros_like(weight_v)

# %%
pf.close()
weight_x = np.array(weight_x)

print(weight_x.shape)

f.close()
# Out:
# (2311, 2960)

# %%
''' Training data converted. NOt testing data '''
test_fname = 'project_2_test/' + 'Data-2_test.csv'
test_sentence_weights = []
test_X, test_X1 = [], []
test_data_Y = []

# %%
test_f = open(test_fname, 'r')

# %%
for i, line in enumerate(test_f):
    if i != 0:
        ''' Splitting the columns based on comma - since it is csv'''
        columns = line.split(',')

        ''' The comma in the actual sentence was represented as [commma] because of csv format, replace that '''
        columns[1] = columns[1].replace('[comma]', ',')
        columns[2] = columns[2].replace('[comma]', ',')

        ''' Some aspect terms are mic in the sentence where computer/mic is present '''
        columns[1] = columns[1].replace('-', ' ')
        columns[2] = columns[2].replace('-', ' ')
        columns[1] = columns[1].replace('/', ' ')
        columns[2] = columns[2].replace('/', ' ')

        ''' NOt used anymore'''
        tokenizer = RegexpTokenizer(r'\w+') # doesn't work if the special char is in the token
        # columns[2] = tokenizer.tokenize(columns[2].lower())

        '''Tokenize the words'''
        columns[1] = word_tokenize(columns[1])
        columns[2] = word_tokenize(columns[2])

        for j, elem in enumerate(columns[1]):
            '''Remove special characters'''
            columns[1][j] = re.sub('[^0-9a-zA-Z]+', '', elem).lower()
            ''' didn't is tokenized as did n't hence following code '''
            if columns[1][j] == 'nt':
                columns[1][j] = 'not'

        for j, elem in enumerate(columns[2]):
            '''Remove special characters'''
            columns[2][j] = re.sub('[^0-9a-zA-Z]+', '', elem).lower()
            ''' didn't is tokenized as did n't hence following code '''
            if columns[2][j] == 'nt':
                columns[2][j] = 'not'

        '''Remove empty string tokens'''
        columns[1] = [x.strip() for x in columns[1] if x.strip() != '']
        columns[2] = [x.strip() for x in columns[2] if x.strip() != '']

        ''' Remove stop words '''
        columns[1] = [word for word in columns[1] if word not in stopwords_set]
        columns[1] = [word for word in columns[1] if word not in stopwords_set]
        columns[2] = [word for word in columns[2] if word not in stopwords_set]

        columns[1] = ' '.join(columns[1])
        columns[2] = ' '.join(columns[2])

        ''' The aspect term location given is not proper - hence extracting the location by ourselves '''
        columns[3] = []
        ''' Finds the location of the aspect term in the sentence '''
        for m in re.finditer(columns[2], columns[1]):
            columns[3].append([m.start(), m.end()])
            ''' since some aspect terms are not surrounded by spaces, hence below code
            NOT USED ANYMORE
            '''
            if m.start() != 0 and columns[1][m.start() - 1] != ' ':
                # columns[1] = columns[1][:m.start()] + ' ' + columns[1][m.start():]
                pass

        ''' Because of adding space in above code, the position is messed up, hence redoing it. '''
        columns[3] = []

        for m in re.finditer(columns[2], columns[1]):
            columns[3].append([m.start(), m.end()])

        ''' Tokenizing the words again '''
        columns[1] = columns[1].split(' ')
        columns[2] = columns[2].split(' ')
        ''' New column to specify the aspect term location in the list '''
        columns.append([])
        columns.append([]) 
        # columns[5] = []
        ''' for multiple positions of aspect term '''
        for elem in columns[3]:
            if elem[0] == 0: #start index of the 1st occurance of the aspect term
                columns[5].append([0])
            else:
                temp_len = elem[0] # assign the start position of the aspect term
                for j, tokens in enumerate(columns[1]):
                    temp_len -= (len(tokens) + 1) # Counting the words till the position - +1 for blank space
                    if temp_len == 0: # Reached the aspect word
                        columns[5].append([j+1])
                        break
            for k in range(len(columns[2])-1): # if multiple words in the aspect term - tag the following words in the sentence
                try:
                    columns[5][-1].append(columns[5][-1][-1]+1)
                except:
                    print(line)
                    print(columns)
                    pass
    
        
        word_wt_list = [[elem, 0] for elem in columns[1]]
        ''' run only if aspect term found, otherwise the weights are zero '''
        if len(columns[5]) >= 1:
            
            ''' Assigning weights to every word based on the distance from the aspect term '''
            for j, elem in enumerate(columns[5]):
                for k, word in enumerate(columns[1]):
                    if k < elem[0]: # Word left to the aspect term
                        dist = abs(elem[0] - k)
                        if word_wt_list[k][1] < 1/dist:
                            word_wt_list[k][1] = 1/dist
                    elif k > elem[-1]: # word right to the aspect term : Aspect term can have multiple words
                        dist = abs(k - elem[-1])
                        if word_wt_list[k][1] < 1/dist:
                            word_wt_list[k][1] = 1/dist
                for aspect_word_loc in elem:
                    word_wt_list[aspect_word_loc][1] = 1.5

        ''' For duplicate words - if it's aspect term - add the weights, if not, then take the weight which is greater, make the other weight as zero '''
        for j, word_1 in enumerate(word_wt_list):
            for k, word_2 in enumerate(word_wt_list[j+1:]):
                if word_1[0] == word_2[0]:
                    if word_1[1] == 1.5 and word_2[1] == 1.5:
                        # print(line)
                        # print(word_wt_list)
                        word_1[1] += 1.5
                        word_2[1] = 0
                    elif word_1[1] < word_2[1]:
                        # print(line)
                        # print(word_wt_list)
                        word_1[1] = word_2[1]
                        word_2[1] = 0
                    elif word_1[1] > word_2[1]:
                        # print(line)
                        # print(word_wt_list)
                        word_2[1] = 0
                    elif word_1[1] == word_2[1]:
                        word_2[1] = 0

        if len(columns[5]) >= 1:
            ''' For removing duplicate words - they have weight zero now'''
            word_wt_list = [elem for elem in word_wt_list if elem[1] != 0]
        else: 
            print(line)
            print(columns)
            print(word_wt_list)

        if len(columns[2]) > 1 and len(columns[5]) > 1:
            # print(line)
            # print(columns)
            # print(word_wt_list)
            pass

        if columns[0] == '2911_0':
            # print(line)
            # print(word_wt_list)
            pass
        if i == 100:
            # break
            pass

        test_X.append(columns[1])
#         test_data_Y.append(columns[4]) # TODO comment this for final
        test_X1.append(' '.join(columns[1]))

        test_sentence_weights.append(word_wt_list)
# Out:
# 456:1_0,In fact I still use manyLegacy programs (Appleworks[comma] FileMaker Pro[comma] Quicken[comma] Photoshop etc)!,Legacy programs,24--39
#
# ['456:1_0', ['fact', 'still', 'use', 'manylegacy', 'programs', 'appleworks', 'filemaker', 'pro', 'quicken', 'photoshop', 'etc'], ['legacy', 'programs'], [[19, 34]], [], []]
# 456:1_0,In fact I still use manyLegacy programs (Appleworks[comma] FileMaker Pro[comma] Quicken[comma] Photoshop etc)!,Legacy programs,24--39
#
# ['456:1_0', ['fact', 'still', 'use', 'manylegacy', 'programs', 'appleworks', 'filemaker', 'pro', 'quicken', 'photoshop', 'etc'], ['legacy', 'programs'], [[19, 34]], [], []]
# [['fact', 0], ['still', 0], ['use', 0], ['manylegacy', 0], ['programs', 0], ['appleworks', 0], ['filemaker', 0], ['pro', 0], ['quicken', 0], ['photoshop', 0], ['etc', 0]]

# %%
test_weight_v = np.zeros_like(vocab, dtype = np.float_)
test_weight_x = []

# %%
pf = open('final_test2.csv', 'w')

pf.write(','.join(vocab))

# pf.write(',class_') # comment this for final TODO


pf.write('\n')
temp_i = -1

# %%
for i, sentence in enumerate(test_sentence_weights):
    for word in sentence:
        try:
            v_index = vocab.index(word[0])
            test_weight_v[v_index] = word[1]
        except:
            temp_i = i
            print(word[0], i)
    test_weight_x.append(test_weight_v)
    if temp_i == i:
        print(sentence)
    if len(sentence) != test_weight_v[np.where(test_weight_v > 0)].shape[0]:
        print(sentence)
        print(len(sentence))
        print(test_weight_v[np.where(test_weight_v > 0)])

    ''' code to write the data to file '''
    temp = [str(j) for j in test_weight_v.tolist()]
    pf.write(','.join(temp))
#     pf.write(','+str(test_data_Y[i])) # comment this for final TODO
    pf.write('\n')
    test_weight_v = np.zeros_like(test_weight_v)
# Out:
# rocket 0
# [['buy', 0.5], ['separate', 1.0], ['ram', 1.5], ['memory', 1.5], ['rocket', 1.0]]
# [['buy', 0.5], ['separate', 1.0], ['ram', 1.5], ['memory', 1.5], ['rocket', 1.0]]
# 5
# [1.  0.5 1.5 1.5]
# bass 1
# sounding 1
# tinny 1
# [['but', 0.25], ['laptop', 0.3333333333333333], ['bass', 0.5], ['weak', 1.0], ['sound', 1.5], ['comes', 1.0], ['sounding', 1.5], ['tinny', 1.0]]
# [['but', 0.25], ['laptop', 0.3333333333333333], ['bass', 0.5], ['weak', 1.0], ['sound', 1.5], ['comes', 1.0], ['sounding', 1.5], ['tinny', 1.0]]
# 8
# [1.5        1.         0.33333333 1.         0.25      ]
# 1400 2
# [['hardware', 1.5], ['seems', 1.0], ['better', 0.5], ['imac', 0.3333333333333333], ['not', 0.25], ['1400', 0.2], ['smaller', 0.16666666666666666]]
# [['hardware', 1.5], ['seems', 1.0], ['better', 0.5], ['imac', 0.3333333333333333], ['not', 0.25], ['1400', 0.2], ['smaller', 0.16666666666666666]]
# 7
# [0.5        1.         0.25       0.16666667 1.5        0.33333333]
# mobility 5
# provided 5
# unmatched 5
# [['also', 0.2], ['excellent', 0.3333333333333333], ['operating', 0.3333333333333333], ['system', 0.5], ['size', 1.0], ['weight', 1.5], ['optimal', 1.0], ['mobility', 0.5], ['durability', 0.25], ['battery', 0.2], ['functions', 0.16666666666666666], ['provided', 0.14285714285714285], ['trackpad', 0.125], ['unmatched', 0.1111111111111111], ['brand', 0.1]]
# [['also', 0.2], ['excellent', 0.3333333333333333], ['operating', 0.3333333333333333], ['system', 0.5], ['size', 1.0], ['weight', 1.5], ['optimal', 1.0], ['mobility', 0.5], ['durability', 0.25], ['battery', 0.2], ['functions', 0.16666666666666666], ['provided', 0.14285714285714285], ['trackpad', 0.125], ['unmatched', 0.1111111111111111], ['brand', 0.1]]
# 15
# [1.         0.1        0.33333333 0.125      0.25       0.16666667
#  0.2        0.2        0.5        1.5        1.         0.33333333]
# advised 6
# [['chatting', 0.16666666666666666], ['acer', 0.2], ['support', 0.25], ['advised', 0.3333333333333333], ['problem', 0.5], ['corrupted', 1.0], ['operating', 1.5], ['system', 1.5], ['files', 1.5]]
# [['chatting', 0.16666666666666666], ['acer', 0.2], ['support', 0.25], ['advised', 0.3333333333333333], ['problem', 0.5], ['corrupted', 1.0], ['operating', 1.5], ['system', 1.5], ['files', 1.5]]
# 9
# [1.5        0.25       0.16666667 1.         1.5        1.5
#  0.2        0.5       ]
# excited 7
# [['wife', 0.1111111111111111], ['excited', 0.125], ['open', 0.14285714285714285], ['box', 0.16666666666666666], ['but', 0.2], ['quickly', 0.25], ['came', 0.3333333333333333], ['see', 0.5], ['not', 1.0], ['function', 1.5]]
# [['wife', 0.1111111111111111], ['excited', 0.125], ['open', 0.14285714285714285], ['box', 0.16666666666666666], ['but', 0.2], ['quickly', 0.25], ['came', 0.3333333333333333], ['see', 0.5], ['not', 1.0], ['function', 1.5]]
# 10
# [0.25       1.5        0.33333333 0.14285714 0.11111111 0.16666667
#  1.         0.2        0.5       ]
# tasks 8
# [['important', 0.1], ['powerful', 0.1111111111111111], ['enough', 0.125], ['tasks', 0.14285714285714285], ['needed', 0.16666666666666666], ['internet', 0.2], ['word', 0.25], ['processing', 0.3333333333333333], ['graphic', 0.5], ['design', 1.0], ['gaming', 1.5]]
# [['important', 0.1], ['powerful', 0.1111111111111111], ['enough', 0.125], ['tasks', 0.14285714285714285], ['needed', 0.16666666666666666], ['internet', 0.2], ['word', 0.25], ['processing', 0.3333333333333333], ['graphic', 0.5], ['design', 1.0], ['gaming', 1.5]]
# 11
# [0.1        1.5        0.25       0.11111111 0.2        0.125
#  0.33333333 1.         0.16666667 0.5       ]
# streaming 9
# [['great', 1.0], ['streaming', 1.5], ['video', 1.5], ['entertainment', 1.0], ['uses', 0.5]]
# [['great', 1.0], ['streaming', 1.5], ['video', 1.5], ['entertainment', 1.0], ['uses', 0.5]]
# 5
# [0.5 1.5 1.  1. ]
# crappy 10
# results 10
# [['sound', 0.25], ['crappy', 0.3333333333333333], ['even', 0.5], ['turn', 1.0], ['volume', 1.5], ['still', 1.0], ['results', 0.5]]
# [['sound', 0.25], ['crappy', 0.3333333333333333], ['even', 0.5], ['turn', 1.0], ['volume', 1.5], ['still', 1.0], ['results', 0.5]]
# 7
# [0.5  1.   0.25 1.5  1.  ]
# mobility 11
# provided 11
# unmatched 11
# [['also', 0.1111111111111111], ['excellent', 1.0], ['operating', 0.14285714285714285], ['system', 0.16666666666666666], ['size', 0.2], ['weight', 0.25], ['optimal', 0.3333333333333333], ['mobility', 0.5], ['durability', 1.5], ['battery', 1.5], ['functions', 1.0], ['provided', 0.5], ['trackpad', 0.3333333333333333], ['unmatched', 0.25], ['brand', 0.2]]
# [['also', 0.1111111111111111], ['excellent', 1.0], ['operating', 0.14285714285714285], ['system', 0.16666666666666666], ['size', 0.2], ['weight', 0.25], ['optimal', 0.3333333333333333], ['mobility', 0.5], ['durability', 1.5], ['battery', 1.5], ['functions', 1.0], ['provided', 0.5], ['trackpad', 0.3333333333333333], ['unmatched', 0.25], ['brand', 0.2]]
# 15
# [0.2        0.2        0.14285714 0.33333333 1.5        1.
#  1.5        0.11111111 0.16666667 0.25       0.33333333 1.        ]
# additionally 12
# ventilation 12
# steam 12
# impossible 12
# [['additionally', 0.08333333333333333], ['barely', 0.09090909090909091], ['ventilation', 0.1], ['system', 0.1111111111111111], ['computer', 0.125], ['even', 0.14285714285714285], ['simple', 0.16666666666666666], ['activity', 0.2], ['watching', 0.25], ['videos', 0.3333333333333333], ['let', 0.5], ['alone', 1.0], ['playing', 1.5], ['steam', 1.5], ['games', 1.5], ['causes', 1.0], ['laptop', 0.5], ['get', 0.3333333333333333], ['hot', 0.25], ['fact', 0.2], ['impossible', 0.16666666666666666], ['keep', 0.14285714285714285], ['lap', 0.125]]
# [['additionally', 0.08333333333333333], ['barely', 0.09090909090909091], ['ventilation', 0.1], ['system', 0.1111111111111111], ['computer', 0.125], ['even', 0.14285714285714285], ['simple', 0.16666666666666666], ['activity', 0.2], ['watching', 0.25], ['videos', 0.3333333333333333], ['let', 0.5], ['alone', 1.0], ['playing', 1.5], ['steam', 1.5], ['games', 1.5], ['causes', 1.0], ['laptop', 0.5], ['get', 0.3333333333333333], ['hot', 0.25], ['fact', 0.2], ['impossible', 0.16666666666666666], ['keep', 0.14285714285714285], ['lap', 0.125]]
# 23
# [0.16666667 0.14285714 1.5        0.5        0.2        0.14285714
#  0.33333333 1.         1.5        0.5        0.125      0.33333333
#  0.11111111 1.         0.2        0.25       0.125      0.25
#  0.09090909]
# mobility 14
# provided 14
# unmatched 14
# [['also', 0.5], ['excellent', 1.0], ['operating', 1.5], ['system', 1.5], ['size', 1.0], ['weight', 0.5], ['optimal', 0.3333333333333333], ['mobility', 0.25], ['durability', 0.16666666666666666], ['battery', 0.14285714285714285], ['functions', 0.125], ['provided', 0.1111111111111111], ['trackpad', 0.1], ['unmatched', 0.09090909090909091], ['brand', 0.08333333333333333]]
# [['also', 0.5], ['excellent', 1.0], ['operating', 1.5], ['system', 1.5], ['size', 1.0], ['weight', 0.5], ['optimal', 0.3333333333333333], ['mobility', 0.25], ['durability', 0.16666666666666666], ['battery', 0.14285714285714285], ['functions', 0.125], ['provided', 0.1111111111111111], ['trackpad', 0.1], ['unmatched', 0.09090909090909091], ['brand', 0.08333333333333333]]
# 15
# [1.         0.08333333 1.5        0.1        0.16666667 0.125
#  0.14285714 0.5        1.5        0.5        0.33333333 1.        ]
# micron 15
# ssd 15
# [['replacing', 1.0], ['hd', 1.5], ['micron', 1.0], ['ssd', 0.5], ['soon', 0.3333333333333333]]
# [['replacing', 1.0], ['hd', 1.5], ['micron', 1.0], ['ssd', 0.5], ['soon', 0.3333333333333333]]
# 5
# [1.         1.5        0.33333333]
# roomy 17
# [['expected', 0.16666666666666666], ['features', 0.2], ['plus', 0.25], ['wide', 0.3333333333333333], ['screen', 0.5], ['roomy', 1.0], ['keyboard', 1.5]]
# [['expected', 0.16666666666666666], ['features', 0.2], ['plus', 0.25], ['wide', 0.3333333333333333], ['screen', 0.5], ['roomy', 1.0], ['keyboard', 1.5]]
# 7
# [0.5        0.2        1.5        0.25       0.16666667 0.33333333]
# additionally 20
# ventilation 20
# steam 20
# impossible 20
# [['additionally', 0.125], ['barely', 0.14285714285714285], ['ventilation', 0.16666666666666666], ['system', 0.2], ['computer', 0.25], ['even', 0.3333333333333333], ['simple', 0.5], ['activity', 1.0], ['watching', 1.5], ['videos', 1.5], ['let', 1.0], ['alone', 0.5], ['playing', 0.3333333333333333], ['steam', 0.25], ['games', 0.2], ['causes', 0.16666666666666666], ['laptop', 0.14285714285714285], ['get', 0.125], ['hot', 0.1111111111111111], ['fact', 0.1], ['impossible', 0.09090909090909091], ['keep', 0.08333333333333333], ['lap', 0.07692307692307693]]
# [['additionally', 0.125], ['barely', 0.14285714285714285], ['ventilation', 0.16666666666666666], ['system', 0.2], ['computer', 0.25], ['even', 0.3333333333333333], ['simple', 0.5], ['activity', 1.0], ['watching', 1.5], ['videos', 1.5], ['let', 1.0], ['alone', 0.5], ['playing', 0.3333333333333333], ['steam', 0.25], ['games', 0.2], ['causes', 0.16666666666666666], ['laptop', 0.14285714285714285], ['get', 0.125], ['hot', 0.1111111111111111], ['fact', 0.1], ['impossible', 0.09090909090909091], ['keep', 0.08333333333333333], ['lap', 0.07692307692307693]]
# 23
# [0.5        0.33333333 0.2        1.         1.         0.08333333
#  0.125      0.5        0.33333333 0.14285714 0.25       1.5
#  0.2        0.16666667 0.1        1.5        0.07692308 0.11111111
#  0.14285714]
# mini 21
# [['like', 0.2], ['mini', 0.25], ['mac', 0.3333333333333333], ['easy', 0.5], ['setup', 1.0], ['install', 1.5], ['but', 1.0], ['learning', 0.5], ['go', 0.3333333333333333], ['could', 0.25], ['use', 0.2], ['tutorial', 0.16666666666666666], ['learn', 0.14285714285714285], ['features', 0.1111111111111111], ['pc', 0.09090909090909091], ['especially', 0.08333333333333333], ['right', 0.07692307692307693], ['mouse', 0.07142857142857142], ['click', 0.06666666666666667], ['menu', 0.0625]]
# [['like', 0.2], ['mini', 0.25], ['mac', 0.3333333333333333], ['easy', 0.5], ['setup', 1.0], ['install', 1.5], ['but', 1.0], ['learning', 0.5], ['go', 0.3333333333333333], ['could', 0.25], ['use', 0.2], ['tutorial', 0.16666666666666666], ['learn', 0.14285714285714285], ['features', 0.1111111111111111], ['pc', 0.09090909090909091], ['especially', 0.08333333333333333], ['right', 0.07692307692307693], ['mouse', 0.07142857142857142], ['click', 0.06666666666666667], ['menu', 0.0625]]
# 20
# [0.2        0.33333333 0.16666667 0.11111111 0.33333333 1.
#  0.5        0.2        0.06666667 0.0625     0.09090909 1.5
#  0.07692308 0.14285714 0.25       0.5        1.         0.08333333
#  0.07142857]
# ux 22
# [['awesome', 0.14285714285714285], ['form', 0.16666666666666666], ['factor', 0.2], ['great', 0.25], ['battery', 0.3333333333333333], ['life', 0.5], ['wonderful', 1.0], ['ux', 1.5]]
# [['awesome', 0.14285714285714285], ['form', 0.16666666666666666], ['factor', 0.2], ['great', 0.25], ['battery', 0.3333333333333333], ['life', 0.5], ['wonderful', 1.0], ['ux', 1.5]]
# 8
# [0.33333333 1.         0.2        0.16666667 0.14285714 0.25
#  0.5       ]
# slowed 23
# significantly 23
# [['boot', 0.3333333333333333], ['slowed', 0.5], ['significantly', 1.0], ['windows', 1.5], ['updates', 1.5], ['installed', 1.0]]
# [['boot', 0.3333333333333333], ['slowed', 0.5], ['significantly', 1.0], ['windows', 1.5], ['updates', 1.5], ['installed', 1.0]]
# 6
# [0.33333333 1.5        1.5        1.        ]
# matches 24
# [['buy', 0.3333333333333333], ['laptop', 0.5], ['matches', 1.0], ['quality', 1.5], ['macbook', 1.0]]
# [['buy', 0.3333333333333333], ['laptop', 0.5], ['matches', 1.0], ['quality', 1.5], ['macbook', 1.0]]
# 5
# [0.33333333 1.5        1.         0.5       ]
# informed 25
# [['also', 0.5], ['informed', 1.0], ['components', 1.5], ['mac', 1.0], ['book', 0.5], ['dirty', 0.3333333333333333]]
# [['also', 0.5], ['informed', 1.0], ['components', 1.5], ['mac', 1.0], ['book', 0.5], ['dirty', 0.3333333333333333]]
# 6
# [1.         1.5        0.5        0.33333333 0.5       ]
# brushed 26
# [['first', 0.2], ['yes', 0.25], ['mac', 0.3333333333333333], ['nice', 0.5], ['brushed', 1.0], ['aluminum', 1.5]]
# [['first', 0.2], ['yes', 0.25], ['mac', 0.3333333333333333], ['nice', 0.5], ['brushed', 1.0], ['aluminum', 1.5]]
# 6
# [0.33333333 0.2        0.25       0.5        1.5       ]
# manylegacy 27
# filemaker 27
# quicken 27
# [['fact', 0.1111111111111111], ['still', 0.125], ['use', 0.14285714285714285], ['manylegacy', 0.16666666666666666], ['programs', 0.2], ['appleworks', 0.25], ['filemaker', 0.3333333333333333], ['pro', 0.5], ['quicken', 1.0], ['photoshop', 1.5], ['etc', 1.0]]
# [['fact', 0.1111111111111111], ['still', 0.125], ['use', 0.14285714285714285], ['manylegacy', 0.16666666666666666], ['programs', 0.2], ['appleworks', 0.25], ['filemaker', 0.3333333333333333], ['pro', 0.5], ['quicken', 1.0], ['photoshop', 1.5], ['etc', 1.0]]
# 11
# [0.14285714 0.2        0.25       0.5        1.         0.125
#  0.11111111 1.5       ]
# sons 29
# schooling 29
# [['computer', 0.25], ['also', 0.3333333333333333], ['awesome', 0.5], ['sons', 1.0], ['virtual', 1.5], ['home', 1.5], ['schooling', 1.5]]
# [['computer', 0.25], ['also', 0.3333333333333333], ['awesome', 0.5], ['sons', 1.0], ['virtual', 1.5], ['home', 1.5], ['schooling', 1.5]]
# 7
# [1.5        0.33333333 0.25       0.5        1.5       ]
# terribly 30
# [['home', 0.125], ['office', 0.14285714285714285], ['gets', 0.16666666666666666], ['plugged', 0.2], ['external', 0.25], ['24', 0.3333333333333333], ['lcd', 0.5], ['screen', 1.5], ['built', 1.5], ['size', 1.5], ['not', 1.0], ['terribly', 0.5], ['important', 0.3333333333333333]]
# [['home', 0.125], ['office', 0.14285714285714285], ['gets', 0.16666666666666666], ['plugged', 0.2], ['external', 0.25], ['24', 0.3333333333333333], ['lcd', 0.5], ['screen', 1.5], ['built', 1.5], ['size', 1.5], ['not', 1.0], ['terribly', 0.5], ['important', 0.3333333333333333]]
# 13
# [1.5        0.5        1.5        0.33333333 0.14285714 1.5
#  0.16666667 0.2        0.125      0.25       0.33333333 1.        ]
# mini 32
# 2010 32
# [['mini', 1.0], ['body', 1.5], ['not', 1.0], ['changed', 0.5], ['since', 0.3333333333333333], ['late', 0.25], ['2010', 0.2], ['good', 0.16666666666666666], ['reason', 0.14285714285714285]]
# [['mini', 1.0], ['body', 1.5], ['not', 1.0], ['changed', 0.5], ['since', 0.3333333333333333], ['late', 0.25], ['2010', 0.2], ['good', 0.16666666666666666], ['reason', 0.14285714285714285]]
# 9
# [0.5        0.33333333 1.5        0.25       0.16666667 1.
#  0.14285714]
# tasks 33
# [['important', 0.16666666666666666], ['powerful', 0.2], ['enough', 0.25], ['tasks', 0.3333333333333333], ['needed', 0.5], ['internet', 1.0], ['word', 1.5], ['processing', 1.5], ['graphic', 1.0], ['design', 0.5], ['gaming', 0.3333333333333333]]
# [['important', 0.16666666666666666], ['powerful', 0.2], ['enough', 0.25], ['tasks', 0.3333333333333333], ['needed', 0.5], ['internet', 1.0], ['word', 1.5], ['processing', 1.5], ['graphic', 1.0], ['design', 0.5], ['gaming', 0.3333333333333333]]
# 11
# [0.16666667 0.33333333 1.5        0.2        1.         0.25
#  1.5        0.5        0.5        1.        ]
# restrictions 34
# [['smaller', 1.0], ['size', 1.5], ['bonus', 1.0], ['space', 0.5], ['restrictions', 0.3333333333333333]]
# [['smaller', 1.0], ['size', 1.5], ['bonus', 1.0], ['space', 0.5], ['restrictions', 0.3333333333333333]]
# 5
# [1.5 1.  0.5 1. ]
# usability 35
# [['excelent', 0.25], ['performance', 0.3333333333333333], ['usability', 0.5], ['presentation', 1.0], ['time', 1.5], ['response', 1.5]]
# [['excelent', 0.25], ['performance', 0.3333333333333333], ['usability', 0.5], ['presentation', 1.0], ['time', 1.5], ['response', 1.5]]
# 6
# [0.25       1.         1.5        1.5        0.33333333]
# breeze 36
# [['battery', 0.2], ['life', 0.25], ['excellent', 1.0], ['display', 0.5], ['downloading', 1.5], ['apps', 1.5], ['breeze', 1.0]]
# [['battery', 0.2], ['life', 0.25], ['excellent', 1.0], ['display', 0.5], ['downloading', 1.5], ['apps', 1.5], ['breeze', 1.0]]
# 7
# [0.2  1.5  0.5  1.5  0.25 1.  ]
# pads 37
# industry 37
# lousy 37
# [['not', 0.5], ['fan', 1.0], ['click', 1.5], ['pads', 1.5], ['industry', 1.0], ['standard', 0.5], ['days', 0.3333333333333333], ['lousy', 0.25], ['internal', 0.2], ['speakers', 0.16666666666666666], ['hard', 0.14285714285714285], ['find', 0.125], ['things', 0.1111111111111111], ['notebook', 0.1], ['like', 0.08333333333333333], ['especially', 0.07692307692307693], ['considering', 0.07142857142857142], ['350', 0.06666666666666667], ['price', 0.0625], ['tag', 0.058823529411764705]]
# [['not', 0.5], ['fan', 1.0], ['click', 1.5], ['pads', 1.5], ['industry', 1.0], ['standard', 0.5], ['days', 0.3333333333333333], ['lousy', 0.25], ['internal', 0.2], ['speakers', 0.16666666666666666], ['hard', 0.14285714285714285], ['find', 0.125], ['things', 0.1111111111111111], ['notebook', 0.1], ['like', 0.08333333333333333], ['especially', 0.07692307692307693], ['considering', 0.07142857142857142], ['350', 0.06666666666666667], ['price', 0.0625], ['tag', 0.058823529411764705]]
# 20
# [0.08333333 1.         0.14285714 0.07142857 1.5        0.0625
#  0.11111111 0.16666667 0.06666667 0.5        0.05882353 0.2
#  0.5        0.125      0.33333333 0.1        0.07692308]
# ssd 39
# silky 39
# [['put', 0.16666666666666666], ['ssd', 0.2], ['use', 0.25], ['21', 0.3333333333333333], ['led', 0.5], ['screen', 1.0], ['set', 1.5], ['silky', 1.0], ['smooth', 0.5]]
# [['put', 0.16666666666666666], ['ssd', 0.2], ['use', 0.25], ['21', 0.3333333333333333], ['led', 0.5], ['screen', 1.0], ['set', 1.5], ['silky', 1.0], ['smooth', 0.5]]
# 9
# [1.         0.16666667 0.5        0.25       1.5        0.33333333
#  0.5       ]
# crappy 40
# results 40
# [['sound', 1.5], ['crappy', 1.0], ['even', 0.5], ['turn', 0.3333333333333333], ['volume', 0.25], ['still', 0.2], ['results', 0.16666666666666666]]
# [['sound', 1.5], ['crappy', 1.0], ['even', 0.5], ['turn', 0.3333333333333333], ['volume', 0.25], ['still', 0.2], ['results', 0.16666666666666666]]
# 7
# [0.5        0.33333333 1.5        0.25       0.2       ]
# mini 42
# 109 42
# microphones 42
# [['mac', 0.2], ['mini', 0.09090909090909091], ['not', 0.5], ['built', 0.1111111111111111], ['mic', 0.125], ['would', 0.14285714285714285], ['seem', 0.16666666666666666], ['os', 0.25], ['109', 0.3333333333333333], ['handle', 1.0], ['external', 1.5], ['microphones', 1.5], ['properly', 1.0]]
# [['mac', 0.2], ['mini', 0.09090909090909091], ['not', 0.5], ['built', 0.1111111111111111], ['mic', 0.125], ['would', 0.14285714285714285], ['seem', 0.16666666666666666], ['os', 0.25], ['109', 0.3333333333333333], ['handle', 1.0], ['external', 1.5], ['microphones', 1.5], ['properly', 1.0]]
# 13
# [0.2        0.11111111 0.16666667 0.25       1.         1.5
#  1.         0.5        0.14285714 0.125     ]
# adjusted 46
# pounding 46
# [['buy', 0.09090909090909091], ['wireless', 0.1], ['mouse', 0.1111111111111111], ['go', 0.125], ['old', 0.14285714285714285], ['school', 0.16666666666666666], ['hate', 0.2], ['pad', 0.25], ['but', 0.3333333333333333], ['knew', 0.5], ['bought', 1.0], ['works', 1.5], ['great', 1.0], ['need', 0.5], ['get', 0.3333333333333333], ['adjusted', 0.25], ['key', 0.2], ['board', 0.16666666666666666], ['used', 0.14285714285714285], ['bigger', 0.125], ['one', 0.1111111111111111], ['pounding', 0.1]]
# [['buy', 0.09090909090909091], ['wireless', 0.1], ['mouse', 0.1111111111111111], ['go', 0.125], ['old', 0.14285714285714285], ['school', 0.16666666666666666], ['hate', 0.2], ['pad', 0.25], ['but', 0.3333333333333333], ['knew', 0.5], ['bought', 1.0], ['works', 1.5], ['great', 1.0], ['need', 0.5], ['get', 0.3333333333333333], ['adjusted', 0.25], ['key', 0.2], ['board', 0.16666666666666666], ['used', 0.14285714285714285], ['bigger', 0.125], ['one', 0.1111111111111111], ['pounding', 0.1]]
# 22
# [0.2        0.125      0.09090909 0.5        0.14285714 0.11111111
#  0.16666667 0.2        0.33333333 0.1        0.16666667 0.14285714
#  0.5        1.         1.         1.5        0.25       0.33333333
#  0.125      0.11111111]
# content 47
# [['use', 0.25], ['mostly', 0.3333333333333333], ['content', 0.5], ['creation', 1.0], ['audio', 1.5], ['video', 1.0], ['photo', 0.5], ['editing', 0.3333333333333333], ['reliable', 0.25]]
# [['use', 0.25], ['mostly', 0.3333333333333333], ['content', 0.5], ['creation', 1.0], ['audio', 1.5], ['video', 1.0], ['photo', 0.5], ['editing', 0.3333333333333333], ['reliable', 0.25]]
# 9
# [0.33333333 1.         1.5        0.5        0.25       0.25
#  1.         0.33333333]
# magsafe 48
# [['note', 0.3333333333333333], ['however', 0.5], ['existing', 1.0], ['magsafe', 1.5], ['accessories', 1.5], ['not', 1.0], ['work', 0.5], ['2', 0.25], ['connection', 0.2]]
# [['note', 0.3333333333333333], ['however', 0.5], ['existing', 1.0], ['magsafe', 1.5], ['accessories', 1.5], ['not', 1.0], ['work', 0.5], ['2', 0.25], ['connection', 0.2]]
# 9
# [0.33333333 1.         0.5        0.5        1.5        0.25
#  1.         0.2       ]
# beats 49
# [['far', 0.14285714285714285], ['beats', 0.16666666666666666], ['computer', 0.2], ['market', 0.25], ['today', 0.3333333333333333], ['built', 0.5], ['well', 1.0], ['battery', 1.5], ['life', 1.5], ['amazing', 1.0]]
# [['far', 0.14285714285714285], ['beats', 0.16666666666666666], ['computer', 0.2], ['market', 0.25], ['today', 0.3333333333333333], ['built', 0.5], ['well', 1.0], ['battery', 1.5], ['life', 1.5], ['amazing', 1.0]]
# 10
# [0.14285714 1.         1.5        0.5        0.25       0.33333333
#  1.         0.2        1.5       ]
# slot 50
# [['one', 0.5], ['still', 1.0], ['cd', 1.5], ['slot', 1.5]]
# [['one', 0.5], ['still', 1.0], ['cd', 1.5], ['slot', 1.5]]
# 4
# [0.5 1.5 1. ]
# 1100 52
# amazon 52
# 1098 52
# coupon 52
# 998 52
# 1070 52
# otd 52
# [['fast', 0.25], ['great', 0.3333333333333333], ['screen', 0.5], ['beautiful', 1.0], ['apps', 1.5], ['laptop', 1.0], ['priced', 0.5], ['1100', 0.3333333333333333], ['apple', 0.25], ['website', 0.2], ['amazon', 0.16666666666666666], ['1098', 0.14285714285714285], ['tax', 0.125], ['plus', 0.1111111111111111], ['10', 0.1], ['coupon', 0.09090909090909091], ['cost', 0.07692307692307693], ['998', 0.07142857142857142], ['1070', 0.058823529411764705], ['otd', 0.05555555555555555]]
# [['fast', 0.25], ['great', 0.3333333333333333], ['screen', 0.5], ['beautiful', 1.0], ['apps', 1.5], ['laptop', 1.0], ['priced', 0.5], ['1100', 0.3333333333333333], ['apple', 0.25], ['website', 0.2], ['amazon', 0.16666666666666666], ['1098', 0.14285714285714285], ['tax', 0.125], ['plus', 0.1111111111111111], ['10', 0.1], ['coupon', 0.09090909090909091], ['cost', 0.07692307692307693], ['998', 0.07142857142857142], ['1070', 0.058823529411764705], ['otd', 0.05555555555555555]]
# 20
# [0.5        0.25       0.25       0.11111111 1.5        0.07692308
#  0.5        1.         1.         0.125      0.33333333 0.1
#  0.2       ]
# log 53
# [['pleased', 0.5], ['fast', 1.0], ['log', 1.5], ['speedy', 1.0], ['wifi', 0.5], ['connection', 0.3333333333333333], ['long', 0.25], ['battery', 0.2], ['life', 0.16666666666666666], ['6', 0.14285714285714285], ['hrs', 0.125]]
# [['pleased', 0.5], ['fast', 1.0], ['log', 1.5], ['speedy', 1.0], ['wifi', 0.5], ['connection', 0.3333333333333333], ['long', 0.25], ['battery', 0.2], ['life', 0.16666666666666666], ['6', 0.14285714285714285], ['hrs', 0.125]]
# 11
# [1.         0.2        0.25       1.         0.14285714 0.5
#  0.125      0.5        0.33333333 0.16666667]
# involving 54
# [['apple', 0.14285714285714285], ['aware', 0.16666666666666666], ['issue', 0.2], ['either', 0.25], ['old', 0.3333333333333333], ['stock', 0.5], ['defective', 1.0], ['design', 1.5], ['involving', 1.0], ['intel', 0.5], ['4000', 0.3333333333333333], ['graphics', 0.25], ['chipset', 0.2]]
# [['apple', 0.14285714285714285], ['aware', 0.16666666666666666], ['issue', 0.2], ['either', 0.25], ['old', 0.3333333333333333], ['stock', 0.5], ['defective', 1.0], ['design', 1.5], ['involving', 1.0], ['intel', 0.5], ['4000', 0.3333333333333333], ['graphics', 0.25], ['chipset', 0.2]]
# 13
# [0.2        0.33333333 0.14285714 0.5        0.5        1.
#  0.25       0.33333333 1.5        0.25       0.16666667 0.2       ]
# receptacle 55
# nor 55
# slot 55
# located 55
# [['no', 1.0], ['hdmi', 1.5], ['receptacle', 1.5], ['nor', 1.0], ['sd', 0.5], ['card', 0.3333333333333333], ['slot', 0.25], ['located', 0.2], ['anywhere', 0.16666666666666666], ['device', 0.14285714285714285]]
# [['no', 1.0], ['hdmi', 1.5], ['receptacle', 1.5], ['nor', 1.0], ['sd', 0.5], ['card', 0.3333333333333333], ['slot', 0.25], ['located', 0.2], ['anywhere', 0.16666666666666666], ['device', 0.14285714285714285]]
# 10
# [0.5        0.14285714 1.5        0.33333333 0.16666667 1.        ]
# tasks 58
# [['important', 0.125], ['powerful', 0.14285714285714285], ['enough', 0.16666666666666666], ['tasks', 0.2], ['needed', 0.25], ['internet', 0.3333333333333333], ['word', 0.5], ['processing', 1.0], ['graphic', 1.5], ['design', 1.5], ['gaming', 1.0]]
# [['important', 0.125], ['powerful', 0.14285714285714285], ['enough', 0.16666666666666666], ['tasks', 0.2], ['needed', 0.25], ['internet', 0.3333333333333333], ['word', 0.5], ['processing', 1.0], ['graphic', 1.5], ['design', 1.5], ['gaming', 1.0]]
# 11
# [0.125      1.         0.5        0.14285714 0.33333333 0.16666667
#  1.         1.5        0.25       1.5       ]
# usability 59
# [['excelent', 0.3333333333333333], ['performance', 0.5], ['usability', 1.0], ['presentation', 1.5], ['time', 1.0], ['response', 0.5]]
# [['excelent', 0.3333333333333333], ['performance', 0.5], ['usability', 1.0], ['presentation', 1.5], ['time', 1.0], ['response', 0.5]]
# 6
# [0.33333333 1.5        1.         0.5        0.5       ]
# yo 61
# practicality 61
# [['yo', 0.5], ['like', 1.0], ['practicality', 1.5], ['laptop', 1.0]]
# [['yo', 0.5], ['like', 1.0], ['practicality', 1.5], ['laptop', 1.0]]
# 4
# [1. 1.]
# ssd 62
# silky 62
# [['put', 0.3333333333333333], ['ssd', 0.5], ['use', 1.0], ['21', 1.5], ['led', 1.5], ['screen', 1.5], ['set', 1.0], ['silky', 0.5], ['smooth', 0.3333333333333333]]
# [['put', 0.3333333333333333], ['ssd', 0.5], ['use', 1.0], ['21', 1.5], ['led', 1.5], ['screen', 1.5], ['set', 1.0], ['silky', 0.5], ['smooth', 0.3333333333333333]]
# 9
# [1.5        0.33333333 0.33333333 1.         1.         1.5
#  1.5       ]
# mc309ll 64
# amazon 64
# 799 64
# mini 64
# 6750m 64
# 512mb 64
# integrated 64
# package 64
# [['like', 0.125], ['new', 0.14285714285714285], ['condition', 0.16666666666666666], ['imac', 0.2], ['mc309ll', 0.25], ['amazon', 0.3333333333333333], ['900', 0.5], ['level', 1.0], ['quad', 1.5], ['core', 1.5], ['25', 1.5], ['ghz', 1.5], ['cpu', 1.5], ['similar', 1.0], ['799', 0.5], ['mini', 0.3333333333333333], ['radeon', 0.25], ['hd', 0.2], ['6750m', 0.16666666666666666], ['512mb', 0.14285714285714285], ['graphic', 0.125], ['card', 0.1111111111111111], ['integrated', 0.09090909090909091], ['intel', 0.08333333333333333], ['4000', 0.07692307692307693], ['even', 0.06666666666666667], ['comes', 0.0625], ['wireless', 0.058823529411764705], ['apple', 0.05555555555555555], ['keyboard', 0.05263157894736842], ['mouse', 0.05], ['put', 0.047619047619047616], ['together', 0.045454545454545456], ['neat', 0.043478260869565216], ['nice', 0.041666666666666664], ['package', 0.04]]
# [['like', 0.125], ['new', 0.14285714285714285], ['condition', 0.16666666666666666], ['imac', 0.2], ['mc309ll', 0.25], ['amazon', 0.3333333333333333], ['900', 0.5], ['level', 1.0], ['quad', 1.5], ['core', 1.5], ['25', 1.5], ['ghz', 1.5], ['cpu', 1.5], ['similar', 1.0], ['799', 0.5], ['mini', 0.3333333333333333], ['radeon', 0.25], ['hd', 0.2], ['6750m', 0.16666666666666666], ['512mb', 0.14285714285714285], ['graphic', 0.125], ['card', 0.1111111111111111], ['integrated', 0.09090909090909091], ['intel', 0.08333333333333333], ['4000', 0.07692307692307693], ['even', 0.06666666666666667], ['comes', 0.0625], ['wireless', 0.058823529411764705], ['apple', 0.05555555555555555], ['keyboard', 0.05263157894736842], ['mouse', 0.05], ['put', 0.047619047619047616], ['together', 0.045454545454545456], ['neat', 0.043478260869565216], ['nice', 0.041666666666666664], ['package', 0.04]]
# 36
# [1.5        1.5        0.06666667 1.         0.125      0.07692308
#  0.5        0.05555556 0.04761905 1.5        0.04166667 0.05263158
#  0.05882353 0.25       1.5        0.16666667 0.11111111 0.08333333
#  1.5        0.2        0.14285714 0.04545455 0.0625     0.04347826
#  0.125      0.2        1.         0.05      ]
# manylegacy 65
# filemaker 65
# quicken 65
# [['fact', 0.125], ['still', 0.14285714285714285], ['use', 0.16666666666666666], ['manylegacy', 0.2], ['programs', 0.25], ['appleworks', 0.3333333333333333], ['filemaker', 0.5], ['pro', 1.0], ['quicken', 1.5], ['photoshop', 1.0], ['etc', 0.5]]
# [['fact', 0.125], ['still', 0.14285714285714285], ['use', 0.16666666666666666], ['manylegacy', 0.2], ['programs', 0.25], ['appleworks', 0.3333333333333333], ['filemaker', 0.5], ['pro', 1.0], ['quicken', 1.5], ['photoshop', 1.0], ['etc', 0.5]]
# 11
# [0.16666667 0.25       0.33333333 1.         0.5        0.14285714
#  0.125      1.        ]
# flawless 66
# finish 66
# [['looks', 0.25], ['feels', 0.3333333333333333], ['solid', 0.5], ['flawless', 1.0], ['finish', 1.5]]
# [['looks', 0.25], ['feels', 0.3333333333333333], ['solid', 0.5], ['flawless', 1.0], ['finish', 1.5]]
# 5
# [0.25       0.5        0.33333333]
# unresponsive 67
# [['thing', 0.08333333333333333], ['dislike', 0.09090909090909091], ['touchpad', 0.1], ['alot', 0.1111111111111111], ['times', 0.125], ['unresponsive', 0.14285714285714285], ['things', 0.16666666666666666], ['dont', 0.2], ['want', 0.25], ['would', 0.3333333333333333], ['recommend', 0.5], ['using', 1.0], ['mouse', 1.5]]
# [['thing', 0.08333333333333333], ['dislike', 0.09090909090909091], ['touchpad', 0.1], ['alot', 0.1111111111111111], ['times', 0.125], ['unresponsive', 0.14285714285714285], ['things', 0.16666666666666666], ['dont', 0.2], ['want', 0.25], ['would', 0.3333333333333333], ['recommend', 0.5], ['using', 1.0], ['mouse', 1.5]]
# 13
# [1.         0.11111111 0.08333333 0.1        0.16666667 0.09090909
#  0.2        0.125      0.5        0.33333333 0.25       1.5       ]
# safely 71
# [['shipped', 1.5], ['quickly', 1.0], ['safely', 0.5]]
# [['shipped', 1.5], ['quickly', 1.0], ['safely', 0.5]]
# 3
# [1.  1.5]
# slot 72
# [['beware', 0.2], ['no', 0.25], ['dvd', 0.3333333333333333], ['slot', 0.5], ['went', 1.0], ['install', 1.5], ['software', 1.5], ['cd', 1.0], ['could', 0.5], ['not', 0.3333333333333333]]
# [['beware', 0.2], ['no', 0.25], ['dvd', 0.3333333333333333], ['slot', 0.5], ['went', 1.0], ['install', 1.5], ['software', 1.5], ['cd', 1.0], ['could', 0.5], ['not', 0.3333333333333333]]
# 10
# [1.5        0.33333333 1.5        0.2        1.         0.33333333
#  1.         0.5        0.25      ]
# mini 73
# [['like', 0.25], ['mini', 0.3333333333333333], ['mac', 0.5], ['easy', 1.0], ['setup', 1.5], ['install', 1.0], ['but', 0.5], ['learning', 0.3333333333333333], ['go', 0.25], ['could', 0.2], ['use', 0.16666666666666666], ['tutorial', 0.14285714285714285], ['learn', 0.125], ['features', 0.1], ['pc', 0.08333333333333333], ['especially', 0.07692307692307693], ['right', 0.07142857142857142], ['mouse', 0.06666666666666667], ['click', 0.0625], ['menu', 0.058823529411764705]]
# [['like', 0.25], ['mini', 0.3333333333333333], ['mac', 0.5], ['easy', 1.0], ['setup', 1.5], ['install', 1.0], ['but', 0.5], ['learning', 0.3333333333333333], ['go', 0.25], ['could', 0.2], ['use', 0.16666666666666666], ['tutorial', 0.14285714285714285], ['learn', 0.125], ['features', 0.1], ['pc', 0.08333333333333333], ['especially', 0.07692307692307693], ['right', 0.07142857142857142], ['mouse', 0.06666666666666667], ['click', 0.0625], ['menu', 0.058823529411764705]]
# 20
# [0.25       0.5        0.14285714 0.1        0.25       1.5
#  0.33333333 0.16666667 0.0625     0.05882353 0.08333333 1.
#  0.07142857 0.125      0.2        1.         0.5        0.07692308
#  0.06666667]
# ssd 76
# [['nice', 0.25], ['stable', 0.3333333333333333], ['fast', 0.5], ['got', 1.0], ['ssd', 1.5]]
# [['nice', 0.25], ['stable', 0.3333333333333333], ['fast', 0.5], ['got', 1.0], ['ssd', 1.5]]
# 5
# [0.5        0.25       0.33333333 1.        ]
# designer 77
# coder 77
# buddy 77
# [['work', 0.5], ['designer', 0.14285714285714285], ['coder', 0.16666666666666666], ['needed', 0.2], ['new', 0.25], ['buddy', 0.3333333333333333], ['not', 1.0], ['gaming', 1.5]]
# [['work', 0.5], ['designer', 0.14285714285714285], ['coder', 0.16666666666666666], ['needed', 0.2], ['new', 0.25], ['buddy', 0.3333333333333333], ['not', 1.0], ['gaming', 1.5]]
# 8
# [1.5  0.5  0.25 1.   0.2 ]
# beats 79
# [['definitely', 0.25], ['beats', 0.3333333333333333], ['old', 0.5], ['mac', 1.0], ['service', 1.5], ['great', 1.0]]
# [['definitely', 0.25], ['beats', 0.3333333333333333], ['old', 0.5], ['mac', 1.0], ['service', 1.5], ['great', 1.0]]
# 6
# [0.25 1.   1.5  0.5  1.  ]
# ios 80
# [['not', 0.07692307692307693], ['sure', 0.08333333333333333], ['going', 0.09090909090909091], ['like', 0.1], ['much', 0.1111111111111111], ['less', 0.125], ['love', 0.14285714285714285], ['went', 0.16666666666666666], ['local', 0.2], ['best', 0.25], ['buy', 0.3333333333333333], ['played', 0.5], ['around', 1.0], ['ios', 1.5], ['system', 1.5], ['mac', 1.0], ['pro', 0.5], ['totally', 0.3333333333333333], ['unique', 0.25], ['different', 0.2]]
# [['not', 0.07692307692307693], ['sure', 0.08333333333333333], ['going', 0.09090909090909091], ['like', 0.1], ['much', 0.1111111111111111], ['less', 0.125], ['love', 0.14285714285714285], ['went', 0.16666666666666666], ['local', 0.2], ['best', 0.25], ['buy', 0.3333333333333333], ['played', 0.5], ['around', 1.0], ['ios', 1.5], ['system', 1.5], ['mac', 1.0], ['pro', 0.5], ['totally', 0.3333333333333333], ['unique', 0.25], ['different', 0.2]]
# 20
# [0.1        1.         0.2        0.25       0.125      0.33333333
#  0.33333333 0.5        0.25       0.2        0.11111111 0.5
#  0.09090909 0.08333333 0.16666667 0.14285714 1.         0.07692308
#  1.5       ]
# ssd 81
# [['add', 0.3333333333333333], ['ssd', 0.5], ['drive', 1.0], ['memory', 1.5]]
# [['add', 0.3333333333333333], ['ssd', 0.5], ['drive', 1.0], ['memory', 1.5]]
# 4
# [0.33333333 1.         1.5       ]
# usb3 82
# mini 82
# [['usb3', 1.5], ['bought', 1.0], ['mini', 0.5]]
# [['usb3', 1.5], ['bought', 1.0], ['mini', 0.5]]
# 3
# [1.]
# mini 84
# [['like', 0.09090909090909091], ['mini', 0.1], ['mac', 0.1111111111111111], ['easy', 0.125], ['setup', 0.14285714285714285], ['install', 0.16666666666666666], ['but', 0.2], ['learning', 0.25], ['go', 0.3333333333333333], ['could', 0.5], ['use', 1.0], ['tutorial', 1.5], ['learn', 1.0], ['features', 0.3333333333333333], ['pc', 0.2], ['especially', 0.16666666666666666], ['right', 0.14285714285714285], ['mouse', 0.125], ['click', 0.1111111111111111], ['menu', 0.1]]
# [['like', 0.09090909090909091], ['mini', 0.1], ['mac', 0.1111111111111111], ['easy', 0.125], ['setup', 0.14285714285714285], ['install', 0.16666666666666666], ['but', 0.2], ['learning', 0.25], ['go', 0.3333333333333333], ['could', 0.5], ['use', 1.0], ['tutorial', 1.5], ['learn', 1.0], ['features', 0.3333333333333333], ['pc', 0.2], ['especially', 0.16666666666666666], ['right', 0.14285714285714285], ['mouse', 0.125], ['click', 0.1111111111111111], ['menu', 0.1]]
# 20
# [0.09090909 0.11111111 1.5        0.33333333 0.33333333 0.14285714
#  0.25       1.         0.11111111 0.1        0.2        0.16666667
#  0.14285714 1.         0.5        0.125      0.2        0.16666667
#  0.125     ]
# dabble 87
# wow 87
# professionally 87
# [['far', 0.2], ['user', 0.25], ['type', 0.3333333333333333], ['dabble', 0.5], ['everything', 1.0], ['games', 1.5], ['wow', 1.0], ['photoshop', 0.5], ['but', 0.3333333333333333], ['nothing', 0.25], ['professionally', 0.2]]
# [['far', 0.2], ['user', 0.25], ['type', 0.3333333333333333], ['dabble', 0.5], ['everything', 1.0], ['games', 1.5], ['wow', 1.0], ['photoshop', 0.5], ['but', 0.3333333333333333], ['nothing', 0.25], ['professionally', 0.2]]
# 11
# [0.2        0.25       1.5        0.25       0.33333333 1.
#  0.5        0.33333333]
# harddrive 88
# [['harddrive', 1.5], ['poor', 1.0], ['condition', 0.5], ['replace', 0.3333333333333333]]
# [['harddrive', 1.5], ['poor', 1.0], ['condition', 0.5], ['replace', 0.3333333333333333]]
# 4
# [0.33333333 0.5        1.        ]
# excited 89
# [['built', 1.5], ['quality', 1.5], ['really', 1.0], ['good', 0.5], ['happy', 0.3333333333333333], ['excited', 0.25], ['product', 0.2]]
# [['built', 1.5], ['quality', 1.5], ['really', 1.0], ['good', 0.5], ['happy', 0.3333333333333333], ['excited', 0.25], ['product', 0.2]]
# 7
# [1.         1.5        1.5        0.2        0.5        0.33333333]
# air 90
# fonts 90
# [['air', 0.25], ['higher', 0.3333333333333333], ['resolution', 0.5], ['but', 1.0], ['fonts', 1.5], ['small', 1.0]]
# [['air', 0.25], ['higher', 0.3333333333333333], ['resolution', 0.5], ['but', 1.0], ['fonts', 1.5], ['small', 1.0]]
# 6
# [0.5        1.         0.33333333 1.        ]
# arrive 93
# [['however', 0.25], ['chose', 0.3333333333333333], ['two', 0.5], ['day', 1.0], ['shipping', 1.5], ['took', 1.0], ['week', 0.5], ['arrive', 0.3333333333333333]]
# [['however', 0.25], ['chose', 0.3333333333333333], ['two', 0.5], ['day', 1.0], ['shipping', 1.5], ['took', 1.0], ['week', 0.5], ['arrive', 0.3333333333333333]]
# 8
# [0.5        1.5        0.5        0.25       1.         0.33333333
#  1.        ]
# inspiron 94
# miss 94
# [['dell', 0.3333333333333333], ['inspiron', 0.5], ['fast', 1.0], ['number', 1.5], ['pad', 1.5], ['keyboard', 1.5], ['miss', 1.0], ['apple', 0.5], ['laptops', 0.3333333333333333]]
# [['dell', 0.3333333333333333], ['inspiron', 0.5], ['fast', 1.0], ['number', 1.5], ['pad', 1.5], ['keyboard', 1.5], ['miss', 1.0], ['apple', 0.5], ['laptops', 0.3333333333333333]]
# 9
# [0.5        1.         1.5        0.33333333 1.5        0.33333333
#  1.5       ]
# photographer 95
# [['needs', 0.14285714285714285], ['professional', 0.16666666666666666], ['photographer', 0.2], ['generally', 0.25], ['need', 0.3333333333333333], ['keep', 0.5], ['best', 1.0], ['specs', 1.5]]
# [['needs', 0.14285714285714285], ['professional', 0.16666666666666666], ['photographer', 0.2], ['generally', 0.25], ['need', 0.3333333333333333], ['keep', 0.5], ['best', 1.0], ['specs', 1.5]]
# 8
# [0.16666667 0.25       1.5        0.5        1.         0.14285714
#  0.33333333]
# samsung 97
# 830 97
# ssd 97
# [['swap', 1.0], ['hard', 1.5], ['drive', 1.5], ['samsung', 1.0], ['830', 0.5], ['ssd', 0.3333333333333333], ['highly', 0.25], ['recommend', 0.2]]
# [['swap', 1.0], ['hard', 1.5], ['drive', 1.5], ['samsung', 1.0], ['830', 0.5], ['ssd', 0.3333333333333333], ['highly', 0.25], ['recommend', 0.2]]
# 8
# [1.5  0.25 1.   0.2  1.5 ]
# mini 98
# [['mac', 0.2], ['mini', 0.25], ['wireless', 0.3333333333333333], ['keyboard', 0.5], ['mouse', 1.0], ['hdmi', 1.5], ['cable', 1.5], ['need', 1.0], ['get', 0.5], ['real', 0.3333333333333333], ['work', 0.25], ['done', 0.2]]
# [['mac', 0.2], ['mini', 0.25], ['wireless', 0.3333333333333333], ['keyboard', 0.5], ['mouse', 1.0], ['hdmi', 1.5], ['cable', 1.5], ['need', 1.0], ['get', 0.5], ['real', 0.3333333333333333], ['work', 0.25], ['done', 0.2]]
# 12
# [1.5        0.2        1.5        0.33333333 0.5        0.5
#  0.33333333 0.25       1.         0.2        1.        ]
# usb3 100
# peripherals 100
# noticably 100
# [['usb3', 1.5], ['peripherals', 1.5], ['noticably', 1.0], ['less', 0.5], ['expensive', 0.3333333333333333], ['thunderbolt', 0.25], ['ones', 0.2]]
# [['usb3', 1.5], ['peripherals', 1.5], ['noticably', 1.0], ['less', 0.5], ['expensive', 0.3333333333333333], ['thunderbolt', 0.25], ['ones', 0.2]]
# 7
# [0.5        0.25       0.2        0.33333333]
# luckily 101
# contemplating 101
# mini 101
# [['luckily', 0.16666666666666666], ['us', 0.2], ['contemplating', 0.25], ['decision', 0.3333333333333333], ['mac', 0.5], ['mini', 1.0], ['priced', 1.5], ['right', 1.0]]
# [['luckily', 0.16666666666666666], ['us', 0.2], ['contemplating', 0.25], ['decision', 0.3333333333333333], ['mac', 0.5], ['mini', 1.0], ['priced', 1.5], ['right', 1.0]]
# 8
# [0.5        0.33333333 0.2        1.5        1.        ]
# deliver 102
# [['not', 1.0], ['look', 1.5], ['good', 1.0], ['deliver', 0.5], ['excellent', 0.3333333333333333], ['performance', 0.25]]
# [['not', 1.0], ['look', 1.5], ['good', 1.0], ['deliver', 0.5], ['excellent', 0.3333333333333333], ['performance', 0.25]]
# 6
# [1.5        1.         1.         0.25       0.33333333]
# 3d 105
# considerably 105
# [['3d', 1.5], ['rendering', 1.5], ['slows', 1.0], ['considerably', 0.5]]
# [['3d', 1.5], ['rendering', 1.5], ['slows', 1.0], ['considerably', 0.5]]
# 4
# [1.5 1. ]
# usability 106
# [['excelent', 0.5], ['performance', 1.0], ['usability', 1.5], ['presentation', 1.0], ['time', 0.5], ['response', 0.3333333333333333]]
# [['excelent', 0.5], ['performance', 1.0], ['usability', 1.5], ['presentation', 1.0], ['time', 0.5], ['response', 0.3333333333333333]]
# 6
# [0.5        1.         0.5        0.33333333 1.        ]
# reopen 108
# [['however', 0.25], ['experience', 0.3333333333333333], ['great', 0.5], ['since', 1.0], ['os', 1.5], ['not', 1.0], ['become', 0.5], ['unstable', 0.3333333333333333], ['application', 0.25], ['simply', 0.2], ['shutdown', 0.16666666666666666], ['reopen', 0.14285714285714285]]
# [['however', 0.25], ['experience', 0.3333333333333333], ['great', 0.5], ['since', 1.0], ['os', 1.5], ['not', 1.0], ['become', 0.5], ['unstable', 0.3333333333333333], ['application', 0.25], ['simply', 0.2], ['shutdown', 0.16666666666666666], ['reopen', 0.14285714285714285]]
# 12
# [0.5        0.25       0.33333333 0.2        1.5        0.33333333
#  0.25       1.         0.16666667 1.         0.5       ]
# air 109
# fonts 109
# [['air', 0.5], ['higher', 1.0], ['resolution', 1.5], ['but', 1.0], ['fonts', 0.5], ['small', 0.3333333333333333]]
# [['air', 0.5], ['higher', 1.0], ['resolution', 1.5], ['but', 1.0], ['fonts', 0.5], ['small', 0.3333333333333333]]
# 6
# [1.5        0.33333333 1.         1.        ]
# ssd 111
# [['add', 1.0], ['ssd', 1.5], ['drive', 1.5], ['memory', 1.0]]
# [['add', 1.0], ['ssd', 1.5], ['drive', 1.5], ['memory', 1.0]]
# 4
# [1.  1.5 1. ]
# ssd 112
# silky 112
# [['put', 1.0], ['ssd', 1.5], ['use', 1.0], ['21', 0.5], ['led', 0.3333333333333333], ['screen', 0.25], ['set', 0.2], ['silky', 0.16666666666666666], ['smooth', 0.14285714285714285]]
# [['put', 1.0], ['ssd', 1.5], ['use', 1.0], ['21', 0.5], ['led', 0.3333333333333333], ['screen', 0.25], ['set', 0.2], ['silky', 0.16666666666666666], ['smooth', 0.14285714285714285]]
# 9
# [0.25       1.         0.14285714 1.         0.2        0.5
#  0.33333333]
# generation 114
# ivy 114
# bridge 114
# haswell 114
# 2013 114
# [['version', 0.25], ['macbook', 0.3333333333333333], ['pro', 0.5], ['runs', 1.0], ['third', 1.5], ['generation', 1.5], ['cpu', 1.5], ['ivy', 1.5], ['bridge', 1.5], ['not', 1.0], ['latest', 0.5], ['fourth', 0.3333333333333333], ['haswell', 0.2], ['2013', 0.14285714285714285]]
# [['version', 0.25], ['macbook', 0.3333333333333333], ['pro', 0.5], ['runs', 1.0], ['third', 1.5], ['generation', 1.5], ['cpu', 1.5], ['ivy', 1.5], ['bridge', 1.5], ['not', 1.0], ['latest', 0.5], ['fourth', 0.3333333333333333], ['haswell', 0.2], ['2013', 0.14285714285714285]]
# 14
# [1.5        0.33333333 0.5        1.5        0.25       0.33333333
#  0.5        1.         1.        ]
# described 117
# [['shipping', 1.5], ['quick', 1.0], ['product', 0.5], ['described', 0.3333333333333333], ['sent', 0.2], ['much', 0.16666666666666666]]
# [['shipping', 1.5], ['quick', 1.0], ['product', 0.5], ['described', 0.3333333333333333], ['sent', 0.2], ['much', 0.16666666666666666]]
# 6
# [0.2        1.5        0.5        0.16666667 1.        ]
# beats 121
# [['speed', 0.14285714285714285], ['multi', 0.16666666666666666], ['touch', 0.2], ['gestures', 0.25], ['operating', 0.3333333333333333], ['system', 0.5], ['beats', 1.0], ['windows', 1.5], ['easily', 1.0]]
# [['speed', 0.14285714285714285], ['multi', 0.16666666666666666], ['touch', 0.2], ['gestures', 0.25], ['operating', 0.3333333333333333], ['system', 0.5], ['beats', 1.0], ['windows', 1.5], ['easily', 1.0]]
# 9
# [0.33333333 1.5        1.         0.14285714 0.16666667 0.5
#  0.25       0.2       ]
# lastly 123
# [['lastly', 1.0], ['windows', 1.5], ['8', 1.5], ['annoying', 1.0]]
# [['lastly', 1.0], ['windows', 1.5], ['8', 1.5], ['annoying', 1.0]]
# 4
# [1.5 1.5 1. ]
# mistake 124
# regard 124
# [['bought', 0.07142857142857142], ['new', 0.07692307692307693], ['macbook', 0.08333333333333333], ['pro', 0.09090909090909091], ['13', 0.1], ['model', 0.1111111111111111], ['ca', 0.125], ['not', 0.14285714285714285], ['believe', 0.16666666666666666], ['apple', 0.2], ['keeps', 0.25], ['making', 0.3333333333333333], ['mistake', 0.5], ['regard', 1.0], ['usb', 1.5], ['ports', 1.5]]
# [['bought', 0.07142857142857142], ['new', 0.07692307692307693], ['macbook', 0.08333333333333333], ['pro', 0.09090909090909091], ['13', 0.1], ['model', 0.1111111111111111], ['ca', 0.125], ['not', 0.14285714285714285], ['believe', 0.16666666666666666], ['apple', 0.2], ['keeps', 0.25], ['making', 0.3333333333333333], ['mistake', 0.5], ['regard', 1.0], ['usb', 1.5], ['ports', 1.5]]
# 16
# [0.2        0.25       0.11111111 0.16666667 0.08333333 0.09090909
#  0.07692308 0.33333333 0.07142857 0.1        0.14285714 0.125
#  1.5        1.5       ]
# mc309ll 125
# amazon 125
# 799 125
# mini 125
# 6750m 125
# 512mb 125
# integrated 125
# package 125
# [['like', 0.043478260869565216], ['new', 0.045454545454545456], ['condition', 0.047619047619047616], ['imac', 0.05], ['mc309ll', 0.05263157894736842], ['amazon', 0.05555555555555555], ['900', 0.058823529411764705], ['level', 0.0625], ['quad', 0.06666666666666667], ['core', 0.07142857142857142], ['25', 0.07692307692307693], ['ghz', 0.08333333333333333], ['cpu', 0.09090909090909091], ['similar', 0.1], ['799', 0.1111111111111111], ['mini', 1.0], ['radeon', 0.14285714285714285], ['hd', 0.16666666666666666], ['6750m', 0.2], ['512mb', 0.25], ['graphic', 0.3333333333333333], ['card', 1.5], ['integrated', 1.5], ['intel', 1.5], ['4000', 1.5], ['even', 1.0], ['comes', 0.5], ['wireless', 0.3333333333333333], ['apple', 0.25], ['keyboard', 0.2], ['mouse', 0.16666666666666666], ['put', 0.14285714285714285], ['together', 0.125], ['neat', 0.1111111111111111], ['nice', 0.1], ['package', 0.09090909090909091]]
# [['like', 0.043478260869565216], ['new', 0.045454545454545456], ['condition', 0.047619047619047616], ['imac', 0.05], ['mc309ll', 0.05263157894736842], ['amazon', 0.05555555555555555], ['900', 0.058823529411764705], ['level', 0.0625], ['quad', 0.06666666666666667], ['core', 0.07142857142857142], ['25', 0.07692307692307693], ['ghz', 0.08333333333333333], ['cpu', 0.09090909090909091], ['similar', 0.1], ['799', 0.1111111111111111], ['mini', 1.0], ['radeon', 0.14285714285714285], ['hd', 0.16666666666666666], ['6750m', 0.2], ['512mb', 0.25], ['graphic', 0.3333333333333333], ['card', 1.5], ['integrated', 1.5], ['intel', 1.5], ['4000', 1.5], ['even', 1.0], ['comes', 0.5], ['wireless', 0.3333333333333333], ['apple', 0.25], ['keyboard', 0.2], ['mouse', 0.16666666666666666], ['put', 0.14285714285714285], ['together', 0.125], ['neat', 0.1111111111111111], ['nice', 0.1], ['package', 0.09090909090909091]]
# 36
# [0.08333333 0.07142857 1.         0.1        0.04347826 1.5
#  0.05882353 0.25       0.14285714 0.07692308 0.1        0.2
#  0.33333333 0.14285714 0.09090909 0.04761905 1.5        1.5
#  0.06666667 0.16666667 0.04545455 0.125      0.5        0.11111111
#  0.33333333 0.05       0.0625     0.16666667]
# mountain 126
# [['but', 1.0], ['mountain', 1.5], ['lion', 1.5], ['slow', 1.0]]
# [['but', 1.0], ['mountain', 1.5], ['lion', 1.5], ['slow', 1.0]]
# 4
# [1.  1.5 1. ]
# complained 129
# released 129
# firmware 129
# patch 129
# [['know', 0.14285714285714285], ['people', 0.16666666666666666], ['complained', 0.2], ['hdmi', 0.25], ['issues', 0.3333333333333333], ['but', 0.5], ['released', 1.0], ['firmware', 1.5], ['patch', 1.5], ['address', 1.0], ['issue', 0.5]]
# [['know', 0.14285714285714285], ['people', 0.16666666666666666], ['complained', 0.2], ['hdmi', 0.25], ['issues', 0.3333333333333333], ['but', 0.5], ['released', 1.0], ['firmware', 1.5], ['patch', 1.5], ['address', 1.0], ['issue', 0.5]]
# 11
# [0.5        0.25       1.         0.14285714 0.33333333 0.5
#  0.16666667]
# thick 130
# [['really', 0.3333333333333333], ['thick', 0.5], ['around', 1.0], ['battery', 1.5]]
# [['really', 0.3333333333333333], ['thick', 0.5], ['around', 1.0], ['battery', 1.5]]
# 4
# [0.33333333 1.5        1.        ]
# gigabit 133
# magsafe 133
# [['ports', 0.16666666666666666], ['include', 0.2], ['firewire', 0.25], ['800', 0.3333333333333333], ['gigabit', 0.5], ['ethernet', 1.0], ['magsafe', 1.5], ['port', 1.5], ['microphone', 1.0], ['jack', 0.5]]
# [['ports', 0.16666666666666666], ['include', 0.2], ['firewire', 0.25], ['800', 0.3333333333333333], ['gigabit', 0.5], ['ethernet', 1.0], ['magsafe', 1.5], ['port', 1.5], ['microphone', 1.0], ['jack', 0.5]]
# 10
# ...
# 21
# [0.33333333 1.         1.5        0.2        0.07692308 0.16666667
#  1.5        0.08333333 0.1        0.16666667 0.125      0.5
#  0.33333333 0.09090909 0.11111111 0.2       ]
# customize 597
# bookmarks 597
# [['easy', 1.0], ['customize', 1.5], ['setting', 1.5], ['even', 1.0], ['create', 0.5], ['bookmarks', 0.3333333333333333]]
# [['easy', 1.0], ['customize', 1.5], ['setting', 1.5], ['even', 1.0], ['create', 0.5], ['bookmarks', 0.3333333333333333]]
# 6
# [1.  0.5 1.5 1. ]
# overbearing 598
# restrictions 598
# [['reasons', 0.3333333333333333], ['pc', 0.5], ['users', 1.0], ['price', 1.5], ['overbearing', 1.0], ['restrictions', 0.5], ['osx', 0.3333333333333333], ['lack', 0.25], ['support', 0.2], ['games', 0.16666666666666666]]
# [['reasons', 0.3333333333333333], ['pc', 0.5], ['users', 1.0], ['price', 1.5], ['overbearing', 1.0], ['restrictions', 0.5], ['osx', 0.3333333333333333], ['lack', 0.25], ['support', 0.2], ['games', 0.16666666666666666]]
# 10
# [0.2        0.16666667 0.25       1.5        0.33333333 0.5
#  1.         0.33333333]
# bedroom 600
# adsl 600
# [['easy', 1.0], ['install', 1.5], ['also', 1.0], ['small', 0.5], ['leave', 0.3333333333333333], ['anywhere', 0.25], ['bedroom', 0.2], ['configure', 0.125], ['adsl', 0.1111111111111111], ['cable', 0.1], ['wifi', 0.09090909090909091]]
# [['easy', 1.0], ['install', 1.5], ['also', 1.0], ['small', 0.5], ['leave', 0.3333333333333333], ['anywhere', 0.25], ['bedroom', 0.2], ['configure', 0.125], ['adsl', 0.1111111111111111], ['cable', 0.1], ['wifi', 0.09090909090909091]]
# 11
# [0.1        0.33333333 0.125      0.5        1.5        1.
#  0.09090909 0.25       1.        ]
# customize 601
# bookmarks 601
# [['easy', 0.25], ['customize', 0.3333333333333333], ['setting', 0.5], ['even', 1.0], ['create', 1.5], ['bookmarks', 1.5]]
# [['easy', 0.25], ['customize', 0.3333333333333333], ['setting', 0.5], ['even', 1.0], ['create', 1.5], ['bookmarks', 1.5]]
# 6
# [1.   1.5  0.5  0.25]
# softwares 602
# supporting 602
# [['softwares', 1.5], ['supporting', 1.0], ['use', 0.5], ['os', 0.3333333333333333], ['makes', 0.25], ['much', 0.2], ['better', 0.16666666666666666]]
# [['softwares', 1.5], ['supporting', 1.0], ['use', 0.5], ['os', 0.3333333333333333], ['makes', 0.25], ['much', 0.2], ['better', 0.16666666666666666]]
# 7
# [0.25       0.5        0.33333333 0.2        0.16666667]
# pleasurable 604
# [['quick', 0.25], ['responsive', 0.3333333333333333], ['makes', 0.5], ['working', 1.0], ['surfing', 1.5], ['computer', 1.0], ['much', 0.5], ['pleasurable', 0.3333333333333333]]
# [['quick', 0.25], ['responsive', 0.3333333333333333], ['makes', 0.5], ['working', 1.0], ['surfing', 1.5], ['computer', 1.0], ['much', 0.5], ['pleasurable', 0.3333333333333333]]
# 8
# [0.5        1.         0.5        0.25       1.         0.33333333
#  1.5       ]
# mini 605
# disappointment 605
# [['but', 1.0], ['performance', 1.5], ['mac', 1.0], ['mini', 0.5], ['huge', 0.3333333333333333], ['disappointment', 0.25]]
# [['but', 1.0], ['performance', 1.5], ['mac', 1.0], ['mini', 0.5], ['huge', 0.3333333333333333], ['disappointment', 0.25]]
# 6
# [1.         0.33333333 1.5        1.        ]
# unmatched 606
# craftmanship 606
# [['apple', 0.16666666666666666], ['unmatched', 0.2], ['product', 0.25], ['quality', 0.3333333333333333], ['aesthetics', 0.5], ['craftmanship', 1.0], ['customer', 1.5], ['service', 1.5]]
# [['apple', 0.16666666666666666], ['unmatched', 0.2], ['product', 0.25], ['quality', 0.3333333333333333], ['aesthetics', 0.5], ['craftmanship', 1.0], ['customer', 1.5], ['service', 1.5]]
# 8
# [0.16666667 1.5        1.5        0.5        0.33333333 0.25      ]
# brilliant 607
# [['incredible', 0.3333333333333333], ['graphics', 0.5], ['brilliant', 1.0], ['colors', 1.5]]
# [['incredible', 0.3333333333333333], ['graphics', 0.5], ['brilliant', 1.0], ['colors', 1.5]]
# 4
# [0.33333333 0.5        1.5       ]
# recessed 608
# upside 608
# nail 608
# slot 608
# accessed 608
# ejecting 608
# [['sd', 1.5], ['card', 1.5], ['reader', 1.5], ['slightly', 1.0], ['recessed', 0.5], ['upside', 0.3333333333333333], ['nail', 0.25], ['slot', 0.2], ['not', 0.14285714285714285], ['accessed', 0.125], ['self', 0.1111111111111111], ['ejecting', 0.1], ['would', 0.08333333333333333], ['issue', 0.07142857142857142], ['but', 0.06666666666666667]]
# [['sd', 1.5], ['card', 1.5], ['reader', 1.5], ['slightly', 1.0], ['recessed', 0.5], ['upside', 0.3333333333333333], ['nail', 0.25], ['slot', 0.2], ['not', 0.14285714285714285], ['accessed', 0.125], ['self', 0.1111111111111111], ['ejecting', 0.1], ['would', 0.08333333333333333], ['issue', 0.07142857142857142], ['but', 0.06666666666666667]]
# 15
# [0.11111111 1.5        0.07142857 1.5        1.5        1.
#  0.14285714 0.08333333 0.06666667]
# smoothness 611
# [['screen', 1.5], ['software', 1.0], ['smoothness', 0.5], ['operating', 0.3333333333333333], ['system', 0.25]]
# [['screen', 1.5], ['software', 1.0], ['smoothness', 0.5], ['operating', 0.3333333333333333], ['system', 0.25]]
# 5
# [1.5        1.         0.33333333 0.25      ]
# gigabit 612
# magsafe 612
# [['ports', 0.125], ['include', 0.14285714285714285], ['firewire', 0.16666666666666666], ['800', 0.2], ['gigabit', 0.25], ['ethernet', 0.3333333333333333], ['magsafe', 0.5], ['port', 1.0], ['microphone', 1.5], ['jack', 1.5]]
# [['ports', 0.125], ['include', 0.14285714285714285], ['firewire', 0.16666666666666666], ['800', 0.2], ['gigabit', 0.25], ['ethernet', 0.3333333333333333], ['magsafe', 0.5], ['port', 1.0], ['microphone', 1.5], ['jack', 1.5]]
# 10
# [1.5        0.16666667 0.33333333 1.5        1.         0.2
#  0.14285714 0.125     ]
# item 613
# [['item', 0.16666666666666666], ['beautiful', 0.2], ['piece', 0.25], ['works', 0.3333333333333333], ['well', 0.5], ['easy', 1.0], ['carry', 1.5], ['handle', 1.0]]
# [['item', 0.16666666666666666], ['beautiful', 0.2], ['piece', 0.25], ['works', 0.3333333333333333], ['well', 0.5], ['easy', 1.0], ['carry', 1.5], ['handle', 1.0]]
# 8
# [0.25       0.5        1.5        1.         0.2        1.
#  0.33333333]
# log 615
# [['pleased', 0.25], ['fast', 0.3333333333333333], ['log', 0.5], ['speedy', 1.0], ['wifi', 1.5], ['connection', 1.5], ['long', 1.0], ['battery', 0.5], ['life', 0.3333333333333333], ['6', 0.25], ['hrs', 0.2]]
# [['pleased', 0.25], ['fast', 0.3333333333333333], ['log', 0.5], ['speedy', 1.0], ['wifi', 1.5], ['connection', 1.5], ['long', 1.0], ['battery', 0.5], ['life', 0.3333333333333333], ['6', 0.25], ['hrs', 0.2]]
# 11
# [0.33333333 0.5        1.         1.         0.25       0.25
#  0.2        1.5        1.5        0.33333333]
# pads 616
# grip 616
# [['thing', 0.3333333333333333], ['dislike', 0.5], ['laptop', 1.0], ['rubber', 1.5], ['pads', 1.5], ['found', 1.0], ['bottom', 0.5], ['computer', 0.3333333333333333], ['grip', 0.25]]
# [['thing', 0.3333333333333333], ['dislike', 0.5], ['laptop', 1.0], ['rubber', 1.5], ['pads', 1.5], ['found', 1.0], ['bottom', 0.5], ['computer', 0.3333333333333333], ['grip', 0.25]]
# 9
# [1.         0.33333333 0.5        0.5        1.         0.33333333
#  1.5       ]
# customization 618
# impossible 618
# [['customization', 1.5], ['mac', 1.0], ['impossible', 0.5]]
# [['customization', 1.5], ['mac', 1.0], ['impossible', 0.5]]
# 3
# [1.]
# item 619
# [['item', 0.3333333333333333], ['beautiful', 0.5], ['piece', 1.0], ['works', 1.5], ['well', 1.0], ['easy', 0.5], ['carry', 0.3333333333333333], ['handle', 0.25]]
# [['item', 0.3333333333333333], ['beautiful', 0.5], ['piece', 1.0], ['works', 1.5], ['well', 1.0], ['easy', 0.5], ['carry', 0.3333333333333333], ['handle', 0.25]]
# 8
# [1.         1.         0.33333333 0.25       0.5        0.5
#  1.5       ]
# wakes 620
# [['wakes', 1.5], ['less', 1.0], ['second', 0.5], ['open', 0.3333333333333333], ['lid', 0.25]]
# [['wakes', 1.5], ['less', 1.0], ['second', 0.5], ['open', 0.3333333333333333], ['lid', 0.25]]
# 5
# [1.         0.33333333 0.25       0.5       ]
# apparent 621
# mini 621
# [['like', 1.0], ['itunes', 1.5], ['apparent', 1.0], ['security', 0.5], ['mini', 0.3333333333333333], ['form', 0.25], ['factor', 0.2], ['nice', 0.16666666666666666], ['graphics', 0.14285714285714285], ['stuff', 0.125]]
# [['like', 1.0], ['itunes', 1.5], ['apparent', 1.0], ['security', 0.5], ['mini', 0.3333333333333333], ['form', 0.25], ['factor', 0.2], ['nice', 0.16666666666666666], ['graphics', 0.14285714285714285], ['stuff', 0.125]]
# 10
# [1.         0.16666667 0.125      0.2        0.14285714 0.25
#  1.5        0.5       ]
# scratches 624
# [['yes', 0.2], ['good', 0.25], ['thing', 0.3333333333333333], ['but', 0.5], ['made', 1.0], ['aluminum', 1.5], ['scratches', 1.0], ['easily', 0.5]]
# [['yes', 0.2], ['good', 0.25], ['thing', 0.3333333333333333], ['but', 0.5], ['made', 1.0], ['aluminum', 1.5], ['scratches', 1.0], ['easily', 0.5]]
# 8
# [0.2        0.5        0.33333333 0.25       1.         1.5
#  0.5       ]
# mini 625
# [['like', 0.07142857142857142], ['mini', 0.07692307692307693], ['mac', 0.08333333333333333], ['easy', 0.09090909090909091], ['setup', 0.1], ['install', 0.1111111111111111], ['but', 0.125], ['learning', 0.14285714285714285], ['go', 0.16666666666666666], ['could', 0.2], ['use', 1.0], ['tutorial', 0.3333333333333333], ['learn', 0.5], ['features', 1.5], ['pc', 0.5], ['especially', 0.3333333333333333], ['right', 0.25], ['mouse', 0.2], ['click', 0.16666666666666666], ['menu', 0.14285714285714285]]
# [['like', 0.07142857142857142], ['mini', 0.07692307692307693], ['mac', 0.08333333333333333], ['easy', 0.09090909090909091], ['setup', 0.1], ['install', 0.1111111111111111], ['but', 0.125], ['learning', 0.14285714285714285], ['go', 0.16666666666666666], ['could', 0.2], ['use', 1.0], ['tutorial', 0.3333333333333333], ['learn', 0.5], ['features', 1.5], ['pc', 0.5], ['especially', 0.3333333333333333], ['right', 0.25], ['mouse', 0.2], ['click', 0.16666666666666666], ['menu', 0.14285714285714285]]
# 20
# [0.07142857 0.08333333 0.33333333 1.5        0.16666667 0.1
#  0.14285714 1.         0.16666667 0.14285714 0.5        0.11111111
#  0.25       0.5        0.2        0.09090909 0.125      0.33333333
#  0.2       ]
# ux 626
# [['awesome', 0.25], ['form', 0.3333333333333333], ['factor', 0.5], ['great', 1.0], ['battery', 1.5], ['life', 1.5], ['wonderful', 1.0], ['ux', 0.5]]
# [['awesome', 0.25], ['form', 0.3333333333333333], ['factor', 0.5], ['great', 1.0], ['battery', 1.5], ['life', 1.5], ['wonderful', 1.0], ['ux', 0.5]]
# 8
# [1.5        1.         0.5        0.33333333 0.25       1.
#  1.5       ]
# admirably 627
# settling 627
# cumbersome 627
# developing 627
# [['last', 0.16666666666666666], ['laptop', 0.2], ['17', 0.25], ['asus', 0.3333333333333333], ['gaming', 0.5], ['machine', 1.0], ['performed', 1.5], ['admirably', 1.0], ['but', 0.5], ['since', 0.3333333333333333], ['built', 0.25], ['desktop', 0.2], ['really', 0.16666666666666666], ['settling', 0.14285714285714285], ['college', 0.125], ['life', 0.1111111111111111], ['found', 0.1], ['wanting', 0.09090909090909091], ['something', 0.08333333333333333], ['smaller', 0.07692307692307693], ['less', 0.07142857142857142], ['cumbersome', 0.06666666666666667], ['not', 0.0625], ['mention', 0.058823529411764705], ['slowly', 0.05263157894736842], ['developing', 0.05], ['problems', 0.047619047619047616], ['ever', 0.045454545454545456], ['bought', 0.041666666666666664], ['4', 0.04], ['years', 0.038461538461538464], ['ago', 0.037037037037037035]]
# [['last', 0.16666666666666666], ['laptop', 0.2], ['17', 0.25], ['asus', 0.3333333333333333], ['gaming', 0.5], ['machine', 1.0], ['performed', 1.5], ['admirably', 1.0], ['but', 0.5], ['since', 0.3333333333333333], ['built', 0.25], ['desktop', 0.2], ['really', 0.16666666666666666], ['settling', 0.14285714285714285], ['college', 0.125], ['life', 0.1111111111111111], ['found', 0.1], ['wanting', 0.09090909090909091], ['something', 0.08333333333333333], ['smaller', 0.07692307692307693], ['less', 0.07142857142857142], ['cumbersome', 0.06666666666666667], ['not', 0.0625], ['mention', 0.058823529411764705], ['slowly', 0.05263157894736842], ['developing', 0.05], ['problems', 0.047619047619047616], ['ever', 0.045454545454545456], ['bought', 0.041666666666666664], ['4', 0.04], ['years', 0.038461538461538464], ['ago', 0.037037037037037035]]
# 32
# [1.         0.04       0.16666667 0.05263158 0.07142857 0.16666667
#  0.1        0.5        0.03846154 0.2        0.25       0.25
#  1.5        0.04545455 0.125      0.33333333 0.09090909 0.03703704
#  0.2        0.04761905 0.04166667 0.0625     0.07692308 0.33333333
#  0.08333333 0.11111111 0.5        0.05882353]
# informed 631
# boards 631
# [['called', 0.14285714285714285], ['toshiba', 0.16666666666666666], ['gave', 0.2], ['serial', 0.25], ['number', 0.3333333333333333], ['informed', 0.5], ['issues', 1.0], ['mother', 1.5], ['boards', 1.5]]
# [['called', 0.14285714285714285], ['toshiba', 0.16666666666666666], ['gave', 0.2], ['serial', 0.25], ['number', 0.3333333333333333], ['informed', 0.5], ['issues', 1.0], ['mother', 1.5], ['boards', 1.5]]
# 9
# [0.14285714 0.33333333 0.25       1.         1.5        0.2
#  0.16666667]
# mini 632
# 8x 632
# audible 632
# [['mac', 0.125], ['mini', 0.14285714285714285], ['8x', 0.16666666666666666], ['smaller', 0.2], ['old', 0.25], ['computer', 0.3333333333333333], ['huge', 0.5], ['bonus', 1.0], ['runs', 1.5], ['quiet', 1.0], ['actually', 0.5], ['fans', 0.3333333333333333], ['not', 0.25], ['audible', 0.2], ['unlike', 0.16666666666666666], ['pc', 0.125]]
# [['mac', 0.125], ['mini', 0.14285714285714285], ['8x', 0.16666666666666666], ['smaller', 0.2], ['old', 0.25], ['computer', 0.3333333333333333], ['huge', 0.5], ['bonus', 1.0], ['runs', 1.5], ['quiet', 1.0], ['actually', 0.5], ['fans', 0.3333333333333333], ['not', 0.25], ['audible', 0.2], ['unlike', 0.16666666666666666], ['pc', 0.125]]
# 16
# [1.         0.16666667 0.125      0.33333333 1.         0.5
#  0.125      0.25       0.33333333 0.5        0.25       0.2
#  1.5       ]
# involving 633
# [['apple', 0.1111111111111111], ['aware', 0.125], ['issue', 0.14285714285714285], ['either', 0.16666666666666666], ['old', 0.2], ['stock', 0.25], ['defective', 0.3333333333333333], ['design', 0.5], ['involving', 1.0], ['intel', 1.5], ['4000', 1.5], ['graphics', 1.5], ['chipset', 1.5]]
# [['apple', 0.1111111111111111], ['aware', 0.125], ['issue', 0.14285714285714285], ['either', 0.16666666666666666], ['old', 0.2], ['stock', 0.25], ['defective', 0.3333333333333333], ['design', 0.5], ['involving', 1.0], ['intel', 1.5], ['4000', 1.5], ['graphics', 1.5], ['chipset', 1.5]]
# 13
# [0.14285714 1.5        0.11111111 0.25       1.5        0.33333333
#  0.16666667 0.2        0.5        1.5        0.125      1.5       ]
# refute 635
# [['however', 0.5], ['refute', 1.0], ['osx', 1.5], ['fast', 1.0]]
# [['however', 0.5], ['refute', 1.0], ['osx', 1.5], ['fast', 1.0]]
# 4
# [1.  0.5 1.5]
# recessed 636
# upside 636
# nail 636
# slot 636
# accessed 636
# ejecting 636
# [['sd', 0.16666666666666666], ['card', 1.5], ['reader', 0.25], ['slightly', 0.3333333333333333], ['recessed', 0.5], ['upside', 1.0], ['nail', 1.5], ['slot', 1.5], ['not', 1.0], ['accessed', 0.5], ['self', 0.3333333333333333], ['ejecting', 0.25], ['would', 0.16666666666666666], ['issue', 0.125], ['but', 0.1111111111111111]]
# [['sd', 0.16666666666666666], ['card', 1.5], ['reader', 0.25], ['slightly', 0.3333333333333333], ['recessed', 0.5], ['upside', 1.0], ['nail', 1.5], ['slot', 1.5], ['not', 1.0], ['accessed', 0.5], ['self', 0.3333333333333333], ['ejecting', 0.25], ['would', 0.16666666666666666], ['issue', 0.125], ['but', 0.1111111111111111]]
# 15
# [0.33333333 0.25       0.125      0.16666667 1.5        0.33333333
#  1.         0.16666667 0.11111111]
# gigabit 637
# magsafe 637
# [['ports', 0.25], ['include', 0.3333333333333333], ['firewire', 0.5], ['800', 1.0], ['gigabit', 1.5], ['ethernet', 1.5], ['magsafe', 1.0], ['port', 0.5], ['microphone', 0.3333333333333333], ['jack', 0.25]]
# [['ports', 0.25], ['include', 0.3333333333333333], ['firewire', 0.5], ['800', 1.0], ['gigabit', 1.5], ['ethernet', 1.5], ['magsafe', 1.0], ['port', 0.5], ['microphone', 0.3333333333333333], ['jack', 0.25]]
# 10
# [0.33333333 0.5        1.5        0.25       0.5        1.
#  0.33333333 0.25      ]

# %%
pf.close()
test_weight_x = np.array(test_weight_x)

print(test_weight_x.shape)

test_f.close()
# Out:
# (638, 2960)

# %%
print(len(test_sentence_weights))
# Out:
# 638
