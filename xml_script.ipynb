# %%
import xml.etree.ElementTree as ET

# %%
tree = ET.parse('xml\Laptop_Train_v2.xml')

# %%
root = tree.getroot()

# %%
root.tag
# Out:
# 'sentences'

# %%
for child in root:
    if
# Out:
# <Element 'sentence' at 0x00000206B76FAE08>
# <Element 'sentence' at 0x00000206B76FAF48>
# <Element 'sentence' at 0x00000206B7701048>
# <Element 'sentence' at 0x00000206B7701228>
# <Element 'sentence' at 0x00000206B77012C8>
# <Element 'sentence' at 0x00000206B7701368>
# <Element 'sentence' at 0x00000206B7701598>
# <Element 'sentence' at 0x00000206B77016D8>
# <Element 'sentence' at 0x00000206B7701778>
# <Element 'sentence' at 0x00000206B77019A8>
# <Element 'sentence' at 0x00000206B7701A48>
# <Element 'sentence' at 0x00000206B7701B88>
# <Element 'sentence' at 0x00000206B7701C28>
# <Element 'sentence' at 0x00000206B7701E58>
# <Element 'sentence' at 0x00000206B7701EF8>
# <Element 'sentence' at 0x00000206B7706098>
# <Element 'sentence' at 0x00000206B76EF4A8>
# <Element 'sentence' at 0x00000206B66ED548>
# <Element 'sentence' at 0x00000206B7706228>
# <Element 'sentence' at 0x00000206B77062C8>
# <Element 'sentence' at 0x00000206B7706368>
# <Element 'sentence' at 0x00000206B7706408>
# ...
